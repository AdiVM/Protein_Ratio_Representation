# %%
import pandas as pd
import os

base = "/Users/adithyamadduri/Downloads/syn65414912"

# Load the key files
df_levels_anml   = pd.read_csv(os.path.join(base, "OhNM2025_ROSMAP_plasma_Soma7k_protein_level_ANML_log10.csv"))
df_levels_log10  = pd.read_csv(os.path.join(base, "OhNM2025_ROSMAP_plasma_Soma7k_protein_level_log10.csv"))
df_protein_meta  = pd.read_csv(os.path.join(base, "OhNM2025_ROSMAP_plasma_Soma7k_protein_metadata.csv"))
df_sample_meta   = pd.read_csv(os.path.join(base, "OhNM2025_ROSMAP_plasma_Soma7k_sample_metadata.csv"))

# Quick checks
print("Protein levels (ANML):", df_levels_anml.shape)
print("Protein levels (log10):", df_levels_log10.shape)
print("Protein metadata:", df_protein_meta.shape)
print("Sample metadata:", df_sample_meta.shape)

# Preview sample metadata (patients)
print("\n=== Sample Metadata Head ===")
print(df_sample_meta.head())

# Preview protein metadata
print("\n=== Protein Metadata Head ===")
print(df_protein_meta.head())
# Out:
# Protein levels (ANML): (973, 7290)
# Protein levels (log10): (973, 7290)
# Protein metadata: (7289, 42)
# Sample metadata: (973, 12)
#
# === Sample Metadata Head ===
#   projid_visit    projid  Visit study  msex  age_at_visit Diagnosis  \
# 0  R4014413_01  R4014413      1  MAP      0     87.876797       MCI
# 1  R5357999_02  R5357999      2  MAP      0     99.071869       AD+
# 2  R7139444_13  R7139444     13  MAP      0     97.935661       NCI
# 3  R7095349_03  R7095349      3  ROS      0     94.182067        AD
# 4  R4364014_00  R4364014      0  MAP      0     92.605065        AD
#
#    cogn_global  apoe_genotype  educ   age_death  Storage_days
# 0    -1.054759           34.0    16   92.783025        6566.0
# 1    -0.988238           23.0    16  102.091718        6566.0
# 2     1.133552           33.0    21  107.679671        4222.0
# 3          NaN           33.0    16   95.310062        6535.0
# 4    -1.429396           33.0    12   97.456537        6535.0
#
# === Protein Metadata Head ===
#       SeqId  SeqIdVersion    SomaId  \
# 0  10000-28             3  SL019233
# 1   10001-7             3  SL002564
# 2  10003-15             3  SL019245
# 3  10006-25             3  SL019228
# 4  10008-43             3  SL019234
#
#                                       TargetFullName Target UniProt  \
# 0                                 Beta-crystallin B2  CRBB2  P43320
# 1  RAF proto-oncogene serine/threonine-protein ki...  c-Raf  P04049
# 2                             Zinc finger protein 41  ZNF41  P51814
# 3                ETS domain-containing protein Elk-1   ELK1  P19419
# 4              Guanylyl cyclase-activating protein 1  GUC1A  P43080
#
#   EntrezGeneID EntrezGeneSymbol Organism Units  ... Cal_PLT22095  \
# 0         1415           CRYBB2    Human   RFU  ...     1.001488
# 1         5894             RAF1    Human   RFU  ...     0.938539
# 2         7592            ZNF41    Human   RFU  ...     0.951456
# 3         2002             ELK1    Human   RFU  ...     1.013871
# 4         2978           GUCA1A    Human   RFU  ...     0.965670
#
#    CalQcRatio_PLT22106_200170  Cal_PLT22094  CalQcRatio_PLT22105_200170  \
# 0                       1.012      1.047152                       1.021
# 1                       1.072      0.908780                       1.060
# 2                       0.921      0.975355                       0.990
# 3                       0.998      1.027476                       1.056
# 4                       1.022      0.971107                       1.037
#
#    Cal_PLT22183  CalQcRatio_PLT22095_200170  ColCheck  \
# 0      1.060092                       1.043      PASS
# 1      0.884825                       1.040      PASS
# 2      0.866162                       0.954      PASS
# 3      1.053735                       1.053      PASS
# 4      0.983789                       1.020      PASS
#
#    CalQcRatio_PLT22094_200170  CalQcRatio_PLT22183_200170  QcReference_200170
# 0                       0.991                       1.026              2304.3
# 1                       1.078                       1.005               327.4
# 2                       0.946                       0.891               173.6
# 3                       1.051                       1.056               543.1
# 4                       1.033                       1.018               473.6
#
# [5 rows x 42 columns]

# %%
# Check if any protein names start with "pTau"
mask = df_protein_meta["TargetFullName"].str.contains("phosph", na=False)

# Show matching rows
ptau_proteins = df_protein_meta[mask]

print("Proteins starting with pTau:", ptau_proteins.shape[0])
print(ptau_proteins[["SeqId", "TargetFullName", "EntrezGeneSymbol"]])
# Out:
# Proteins starting with pTau: 312
#          SeqId                                     TargetFullName  \
# 6     10011-65        Inositol polyphosphate 5-phosphatase OCRL-1
# 15     10035-6             Dual specificity protein phosphatase 4
# 18    10039-32                    Purine nucleoside phosphorylase
# 36    10070-22  1-phosphatidylinositol 4,5-bisphosphate phosph...
# 37    10073-22                    Tyrosyl-DNA phosphodiesterase 1
# ...        ...                                                ...
# 7209   9867-23              Fructose-1,6-bisphosphatase isozyme 2
# 7216   9876-20                   Fructose-bisphosphate aldolase C
# 7238    9910-9            S-methyl-5'-thioadenosine phosphorylase
# 7255   9940-35                    Dual specificity phosphatase 28
# 7286    9995-6  Deoxyuridine 5'-triphosphate nucleotidohydrola...
#
#      EntrezGeneSymbol
# 6                OCRL
# 15              DUSP4
# 18                PNP
# 36              PLCG2
# 37               TDP1
# ...               ...
# 7209             FBP2
# 7216            ALDOC
# 7238             MTAP
# 7255           DUSP28
# 7286              DUT
#
# [312 rows x 3 columns]

# %%
df_levels_log10
# Out:
#     projid_visit  10000-28   10001-7  10003-15  10006-25  10008-43  10010-10  \
# 0    R4014413_01  2.838219  2.552181  2.247973  2.778224  2.664172  2.563481
# 1    R5357999_02  2.723784  3.127494  2.191171  2.740600  2.662569  2.531479
# 2    R7139444_13  2.789933  2.722552  2.222196  2.736078  2.677881  2.517724
# 3    R7095349_03  2.735759  2.502017  2.183555  2.716838  2.655523  2.553155
# 4    R4364014_00  2.682326  2.510277  2.217221  2.723291  2.686815  2.513084
# ..           ...       ...       ...       ...       ...       ...       ...
# 968  R4971237_09  2.811307  2.513351  2.202761  2.757396  2.637390  2.508664
# 969  R3631183_06  2.908110  2.444357  2.424882  2.685025  2.649432  2.536053
# 970  R9047934_02  2.737352  2.507451  2.285332  2.729489  2.617943  2.552668
# 971  R1467885_03  2.893373  2.708591  2.220631  2.815312  2.591399  2.494155
# 972  R3690777_10  2.742332  2.442480  2.372175  2.736476  2.708761  2.539452
#
#      10011-65   10012-5  10014-31  ...   9984-12   9986-14   9987-30  \
# 0    3.206043  3.142921  2.970440  ...  2.798443  3.446755  2.718834
# 1    3.411081  3.132644  2.972804  ...  2.770705  4.072033  2.705265
# 2    3.319023  3.203441  2.971971  ...  2.867939  3.529097  2.741152
# 3    3.311775  3.099819  2.939170  ...  2.736078  3.863858  2.665018
# 4    3.378271  3.135673  2.932981  ...  2.823279  3.980044  2.701654
# ..        ...       ...       ...  ...       ...       ...       ...
# 968  3.262736  3.165452  2.971090  ...  2.800236  3.198932  2.820267
# 969  3.375682  3.177248  2.972619  ...  2.799409  3.706402  2.754272
# 970  3.245044  3.043441  2.899875  ...  2.732715  3.974972  2.661434
# 971  3.187295  3.146748  2.978181  ...  2.780677  3.612296  2.697926
# 972  3.411670  3.153479  2.974466  ...  2.778730  3.969714  2.717171
#
#       9989-12  9991-112   9993-11  9994-217    9995-6   9997-12    9999-1
# 0    2.745777  2.649627  3.256958  3.191591  3.166756  3.867968  3.149219
# 1    2.631139  2.561578  3.029546  3.145631  3.287085  4.088122  3.247531
# 2    2.686279  2.690816  3.220553  3.230423  3.136752  3.852108  3.058768
# 3    2.687529  2.590284  3.112069  3.152319  3.720821  3.932596  3.117172
# 4    2.663041  2.573220  3.056180  3.149465  3.069742  3.801829  3.047898
# ..        ...       ...       ...       ...       ...       ...       ...
# 968  2.670339  2.683767  3.279051  3.193903  3.162146  3.933163  3.068000
# 969  2.679610  2.828273  3.182101  3.620573  3.051153  3.677242  2.956409
# 970  2.696356  2.884625  3.045675  3.202298  3.184180  3.985507  3.230398
# 971  2.709524  2.656098  3.310290  3.199426  3.478812  4.283419  3.610937
# 972  2.682686  2.850095  3.119256  3.199837  3.098436  3.856783  3.028042
#
# [973 rows x 7290 columns]

# %%
# =========================
# BLOCK 1 — PREPROCESSING
# =========================
import os
import numpy as np
import pandas as pd
from sklearn.preprocessing import OneHotEncoder

# ---- File paths ----
BASE = "/Users/adithyamadduri/Downloads/syn65414912"
ANML_PATH   = os.path.join(BASE, "OhNM2025_ROSMAP_plasma_Soma7k_protein_level_ANML_log10.csv")
SAMPLE_PATH = os.path.join(BASE, "OhNM2025_ROSMAP_plasma_Soma7k_sample_metadata.csv")

# ---- Load ----
df_levels = pd.read_csv(ANML_PATH)        # rows: projid_visit, cols: proteins
df_meta   = pd.read_csv(SAMPLE_PATH)      # contains projid_visit, projid, msex, age_at_visit, educ, apoe_genotype, Diagnosis

# ---- Sanity: keys present? ----
assert "projid_visit" in df_levels.columns, "projid_visit missing in protein matrix."
for col in ["projid_visit","projid","msex","age_at_visit","educ","apoe_genotype","Diagnosis"]:
    assert col in df_meta.columns, f"{col} missing in sample metadata."

# ---- Align on visit ----
# inner join so we only keep visits present in BOTH
df = pd.merge(df_meta, df_levels, on="projid_visit", how="inner", validate="one_to_one")
print("Aligned shape:", df.shape)

# ---- Labels (four groups) ----
df["Diagnosis"] = df["Diagnosis"].astype(str).str.strip()
valid_classes = {"MCI","NCI","AD","AD+"}
df = df[df["Diagnosis"].isin(valid_classes)].reset_index(drop=True)
print("Class counts:\n", df["Diagnosis"].value_counts())

# ---- Grouping key for leakage control ----
df["projid"] = df["projid"].astype(str)

# ---- Stratification label: Diagnosis × sex (0/1) ----
df["msex"] = df["msex"].astype(int)
df["strata"] = df["Diagnosis"] + "_" + df["msex"].astype(str)

# ---- APOE one-hot (Unknown for NaN) ----
def format_apoe(x):
    if pd.isna(x):
        return "Unknown"
    try:
        # e.g., 33.0 -> "33"
        return str(int(float(x)))
    except Exception:
        s = str(x).strip()
        return s if s else "Unknown"

df["apoe_str"] = df["apoe_genotype"].apply(format_apoe)

# scikit-learn compatibility across versions
try:
    ohe = OneHotEncoder(sparse_output=False, handle_unknown="ignore")
except TypeError:
    ohe = OneHotEncoder(sparse=False, handle_unknown="ignore")

apoe_ohe = ohe.fit_transform(df[["apoe_str"]])
apoe_cols = [c.replace("apoe_str_","APOE_") for c in ohe.get_feature_names_out()]
df_apoe  = pd.DataFrame(apoe_ohe, columns=apoe_cols, index=df.index)

# ---- Numeric covariates (unscaled) ----
for col in ["age_at_visit","educ"]:
    df[col] = pd.to_numeric(df[col], errors="coerce")

# ---- Protein feature columns ----
protein_cols = [c for c in df_levels.columns if c != "projid_visit"]

# ---- Final feature matrix X ----
X = pd.concat([df[["age_at_visit","educ"]], df_apoe, df[protein_cols]], axis=1)
y = df["Diagnosis"].astype(str).values
groups = df["projid"].values
strata = df["strata"].values

print("X shape:", X.shape)
print("APOE levels seen:", sorted(set(df["apoe_str"])))
# Out:
# Aligned shape: (973, 7301)
# Class counts:
#  Diagnosis
# NCI    507
# MCI    262
# AD     167
# AD+     17
# Name: count, dtype: int64
# X shape: (953, 7298)
# APOE levels seen: ['22', '23', '24', '33', '34', '44', 'Unknown']

# %%
# === VISIT-LEVEL SUMMARY (standalone) ===
print("\n=== Visit-level summary ===")
print(f"Total patient visits: {len(df)}")

# Visits per diagnosis class (NCI, MCI, AD, AD+), missing classes shown as 0
order = ["NCI", "MCI", "AD", "AD+"]
counts = df["Diagnosis"].value_counts().reindex(order).fillna(0).astype(int)

print("Visits per class:")
for cls, cnt in counts.items():
    print(f"  {cls}: {cnt}")
# Out:
# === Visit-level summary ===
# Total patient visits: 953
# Visits per class:
#   NCI: 507
#   MCI: 262
#   AD: 167
#   AD+: 17

# %%
# =========================
# BLOCK 2 — TRAINING RF
# =========================
import os
import numpy as np
import pandas as pd
from flaml import AutoML
from sklearn.metrics import roc_auc_score

# ---- Output folder ----
out_dir = "/Users/adithyamadduri/Desktop/Projects/proteomics_RF(ANML+Meta)"
os.makedirs(out_dir, exist_ok=True)

# ---- Helper: group-aware stratified 70/30 split (by mode of strata per subject) ----
def group_stratified_shuffle_split(df_index, strata_all, groups_all, test_size=0.30, random_state=0):
    """Return train_idx, test_idx ensuring groups stay intact and class-sex balance is approx preserved.
       Strategy: assign each group a single stratum = mode(strata) among its rows, then stratified split at group level.
    """
    rng = np.random.RandomState(random_state)
    data = pd.DataFrame({"idx": df_index, "strata": strata_all, "group": groups_all})

    # group -> mode(strata)
    grp_mode = (
        data.groupby("group")["strata"]
        .agg(lambda s: s.value_counts().idxmax())
    )
    grp_mode = grp_mode.sample(frac=1.0, random_state=random_state)  # shuffle groups

    train_groups, test_groups = [], []
    for s_val, grp_ids in grp_mode.groupby(grp_mode.values):
        g_list = list(grp_ids.index)
        rng.shuffle(g_list)
        n_test = max(1, int(round(test_size * len(g_list))))
        test_groups.extend(g_list[:n_test])
        train_groups.extend(g_list[n_test:])

    train_mask = np.isin(groups_all, train_groups)
    test_mask  = np.isin(groups_all,  test_groups)
    return np.where(train_mask)[0], np.where(test_mask)[0]

# ---- Classes & seeds ----
classes = ["MCI","NCI","AD","AD+"]     # will save AD+ as 'ADplus' in filenames
def safe_cls(c): return c.replace("+","plus").replace(" ","_").replace("/","-")

seeds = [1,2,3,4,5]

# ---- Main loop ----
for seed in seeds:
    tr_idx, te_idx = group_stratified_shuffle_split(
        df_index=np.arange(len(X)),
        strata_all=strata,
        groups_all=groups,
        test_size=0.30,
        random_state=seed,
    )

    X_train, X_test = X.iloc[tr_idx], X.iloc[te_idx]
    y_train_full    = y[tr_idx]
    y_test_full     = y[te_idx]

    print(f"\n[Seed {seed}] Train n={len(tr_idx)} | Test n={len(te_idx)} | "
          f"Groups train={len(np.unique(groups[tr_idx]))} test={len(np.unique(groups[te_idx]))}")

    for cls in classes:
        y_train = (y_train_full == cls).astype(int)
        y_test  = (y_test_full  == cls).astype(int)

        automl = AutoML()
        settings = {
            "time_budget": 100,               # seconds per class; adjust if you want longer searches
            "metric": "roc_auc",
            "task": "classification",
            "eval_method": "cv",
            "estimator_list": ["rf"],       # force random forest
            "log_file_name": os.path.join(out_dir, f"flaml_seed{seed}_{safe_cls(cls)}.log"),
            "seed": seed,
        }
        automl.fit(X_train=X_train, y_train=y_train, **settings)
        automl.pickle(os.path.join(out_dir, f"seed{seed}_{safe_cls(cls)}_automl.pkl"))

        # Predict proba for positive class
        y_score = automl.predict_proba(X_test)[:, 1]
        auc = roc_auc_score(y_test, y_score) if (y_test.sum() > 0 and y_test.sum() < len(y_test)) else float("nan")
        print(f"  [{cls}] AUC={auc:.3f}")

        # Save per-class CSV for your existing averaging/plotting script
        out_csv = os.path.join(out_dir, f"seed{seed}_{safe_cls(cls)}.csv")
        pd.DataFrame({"y_true": y_test.astype(int), "y_score": y_score.astype(float)}).to_csv(out_csv, index=False)
# Out:
# [Seed 1] Train n=670 | Test n=283 | Groups train=610 test=261
# [flaml.automl.logger: 09-01 22:00:46] {1752} INFO - task = classification
# [flaml.automl.logger: 09-01 22:00:46] {1763} INFO - Evaluation method: cv
# [flaml.automl.logger: 09-01 22:00:46] {1862} INFO - Minimizing error metric: 1-roc_auc
# [flaml.automl.logger: 09-01 22:00:46] {1979} INFO - List of ML learners in AutoML Run: ['rf']
# [flaml.automl.logger: 09-01 22:00:46] {2282} INFO - iteration 0, current learner rf
# [flaml.automl.logger: 09-01 22:00:47] {2417} INFO - Estimated sufficient time budget=11642s. Estimated necessary time budget=12s.
# [flaml.automl.logger: 09-01 22:00:47] {2466} INFO -  at 2.8s,	estimator rf's best error=0.4638,	best estimator rf's best error=0.4638
# [flaml.automl.logger: 09-01 22:00:47] {2282} INFO - iteration 1, current learner rf
# [flaml.automl.logger: 09-01 22:00:49] {2466} INFO -  at 4.1s,	estimator rf's best error=0.4638,	best estimator rf's best error=0.4638
# [flaml.automl.logger: 09-01 22:00:49] {2282} INFO - iteration 2, current learner rf
# [flaml.automl.logger: 09-01 22:00:50] {2466} INFO -  at 5.1s,	estimator rf's best error=0.4417,	best estimator rf's best error=0.4417
# [flaml.automl.logger: 09-01 22
INFO - iteration 39, current learner rf
# [flaml.automl.logger: 09-01 22:33:17] {2466} INFO -  at 60.9s,	estimator rf's best error=0.0268,	best estimator rf's best error=0.0268
# [flaml.automl.logger: 09-01 22:33:17] {2282} INFO - iteration 40, current learner rf
# [flaml.automl.logger: 09-01 22:33:18] {2466} INFO -  at 62.7s,	estimator rf's best error=0.0253,	best estimator rf's best error=0.0253
# [flaml.automl.logger: 09-01 22:33:18] {2282} INFO - iteration 41, current learner rf
# [flaml.automl.logger: 09-01 22:33:20] {2466} INFO -  at 64.5s,	estimator rf's best error=0.0091,	best estimator rf's best error=0.0091
# [flaml.automl.logger: 09-01 22:33:20] {2282} INFO - iteration 42, current learner rf
# [flaml.automl.logger: 09-01 22:33:23] {2466} INFO -  at 66.9s,	estimator rf's best error=0.0091,	best estimator rf's best error=0.0091
# [flaml.automl.logger: 09-01 22:33:23] {2282} INFO - iteration 43, current learner rf
# [flaml.automl.logger: 09-01 22:33:25] {2466} INFO -  at 69.8s,	estimator rf's best error=0.0091,	best estimator rf's best error=0.0091
# [flaml.automl.logger: 09-01 22:33:25] {2282} INFO - iteration 44, current learner rf
# [flaml.automl.logger: 09-01 22:33:28] {2466} INFO -  at 71.8s,	estimator rf's best error=0.0091,	best estimator rf's best error=0.0091
# [flaml.automl.logger: 09-01 22:33:28] {2282} INFO - iteration 45, current learner rf
# [flaml.automl.logger: 09-01 22:33:30] {2466} INFO -  at 74.8s,	estimator rf's best error=0.0091,	best estimator rf's best error=0.0091
# [flaml.automl.logger: 09-01 22:33:30] {2282} INFO - iteration 46, current learner rf
# [flaml.automl.logger: 09-01 22:33:32] {2466} INFO -  at 76.8s,	estimator rf's best error=0.0091,	best estimator rf's best error=0.0091
# [flaml.automl.logger: 09-01 22:33:32] {2282} INFO - iteration 47, current learner rf
# [flaml.automl.logger: 09-01 22:33:34] {2466} INFO -  at 78.5s,	estimator rf's best error=0.0091,	best estimator rf's best error=0.0091
# [flaml.automl.logger: 09-01 22:33:34] {2282} INFO - iteration 48, current learner rf
# [flaml.automl.logger: 09-01 22:33:36] {2466} INFO -  at 80.8s,	estimator rf's best error=0.0091,	best estimator rf's best error=0.0091
# [flaml.automl.logger: 09-01 22:33:36] {2282} INFO - iteration 49, current learner rf
# [flaml.automl.logger: 09-01 22:33:41] {2466} INFO -  at 85.3s,	estimator rf's best error=0.0091,	best estimator rf's best error=0.0091
# [flaml.automl.logger: 09-01 22:33:41] {2282} INFO - iteration 50, current learner rf
# [flaml.automl.logger: 09-01 22:33:42] {2466} INFO -  at 86.8s,	estimator rf's best error=0.0091,	best estimator rf's best error=0.0091
# [flaml.automl.logger: 09-01 22:33:42] {2282} INFO - iteration 51, current learner rf
# [flaml.automl.logger: 09-01 22:33:44] {2466} INFO -  at 88.7s,	estimator rf's best error=0.0091,	best estimator rf's best error=0.0091
# [flaml.automl.logger: 09-01 22:33:44] {2282} INFO - iteration 52, current learner rf
# [flaml.automl.logger: 09-01 22:33:46] {2466} INFO -  at 90.6s,	estimator rf's best error=0.0091,	best estimator rf's best error=0.0091
# [flaml.automl.logger: 09-01 22:33:46] {2282} INFO - iteration 53, current learner rf
# [flaml.automl.logger: 09-01 22:33:48] {2466} INFO -  at 92.2s,	estimator rf's best error=0.0091,	best estimator rf's best error=0.0091
# [flaml.automl.logger: 09-01 22:33:48] {2282} INFO - iteration 54, current learner rf
# [flaml.automl.logger: 09-01 22:33:52] {2466} INFO -  at 96.4s,	estimator rf's best error=0.0091,	best estimator rf's best error=0.0091
# [flaml.automl.logger: 09-01 22:33:52] {2282} INFO - iteration 55, current learner rf
# [flaml.automl.logger: 09-01 22:33:54] {2466} INFO -  at 97.9s,	estimator rf's best error=0.0091,	best estimator rf's best error=0.0091
# [flaml.automl.logger: 09-01 22:33:54] {2282} INFO - iteration 56, current learner rf
# [flaml.automl.logger: 09-01 22:33:55] {2466} INFO -  at 99.7s,	estimator rf's best error=0.0091,	best estimator rf's best error=0.0091
# [flaml.automl.logger: 09-01 22:33:56] {2724} INFO - retrain rf for 0.7s
# [flaml.automl.logger: 09-01 22:33:56] {2727} INFO - retrained model: RandomForestClassifier(criterion='entropy', max_features=0.04331218723163101,
#                        max_leaf_nodes=7, n_estimators=84, n_jobs=-1,
#                        random_state=12032022)
# [flaml.automl.logger: 09-01 22:33:56] {2009} INFO - fit succeeded
# [flaml.automl.logger: 09-01 22:33:56] {2010} INFO - Time taken to find the best model: 64.54541683197021
#   [AD+] AUC=0.538

# %%
import os, glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# ---- Mean ROC across seeds from saved CSVs ----
folder = "/Users/adithyamadduri/Desktop/Projects/proteomics_RF(ANML+Meta)"
files = glob.glob(os.path.join(folder, "seed*_*.csv"))
assert len(files) > 0, "No per-seed ROC CSVs found."

# Infer class names from filenames (everything after 'seedX_')
def class_from_path(p):
    base = os.path.basename(p)
    return "_".join(base.split("_")[1:]).rsplit(".csv", 1)[0]

class_names = sorted(set(class_from_path(p) for p in files))

fpr_grid = np.linspace(0.0, 1.0, 200)

plt.figure(figsize=(10, 8))

for cls in class_names:
    cls_files = sorted(glob.glob(os.path.join(folder, f"seed*_{cls}.csv")))
    if not cls_files:
        continue

    tprs_interp, aucs = [], []

    for path in cls_files:
        df = pd.read_csv(path)
        y_true  = df["y_true"].astype(int).values
        y_score = df["y_score"].astype(float).values
        if np.unique(y_true).size < 2:
            # degenerate split; skip so it doesn't skew means
            continue

        # MATCH ratios convention: raw fpr/tpr, no dedup, no forcing tpr[-1]=1.0
        fpr, tpr, _ = roc_curve(y_true, y_score)

        # Interpolate to common grid for plotting only
        tpr_i = np.interp(fpr_grid, fpr, tpr)
        tpr_i[0] = 0.0
        tprs_interp.append(tpr_i)

        # Scalar AUC from raw fpr/tpr
        aucs.append(auc(fpr, tpr))

    if not tprs_interp:
        continue

    mean_tpr = np.mean(tprs_interp, axis=0)
    std_tpr  = np.std(tprs_interp, axis=0)
    mean_auc = float(np.mean(aucs))
    std_auc  = float(np.std(aucs))

    plt.plot(
        fpr_grid, mean_tpr, lw=2,
        label=f"{cls.replace('_',' ')} (AUC = {mean_auc:.3f} ± {std_auc:.3f})"
    )
    plt.fill_between(
        fpr_grid,
        np.clip(mean_tpr - std_tpr, 0, 1),
        np.clip(mean_tpr + std_tpr, 0, 1),
        alpha=0.15
    )

# Chance line
plt.plot([0, 1], [0, 1], 'k--', label='Chance (AUC = 0.50)')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('RF (Proteomics + Metadata)')
plt.legend(loc='lower right', fontsize=9)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# =========================
# BLOCK 2 — TRAINING
# =========================
import os
import numpy as np
import pandas as pd
from flaml import AutoML
from sklearn.metrics import roc_auc_score

# ---- Output folder ----
out_dir = "/Users/adithyamadduri/Desktop/Projects/proteomics_LGBM(ANML+Meta)"
os.makedirs(out_dir, exist_ok=True)

# ---- Helper: group-aware stratified 70/30 split (by mode of strata per subject) ----
def group_stratified_shuffle_split(df_index, strata_all, groups_all, test_size=0.30, random_state=0):
    """Return train_idx, test_idx ensuring groups stay intact and class-sex balance is approx preserved.
       Strategy: assign each group a single stratum = mode(strata) among its rows, then stratified split at group level.
    """
    rng = np.random.RandomState(random_state)
    data = pd.DataFrame({"idx": df_index, "strata": strata_all, "group": groups_all})

    # group -> mode(strata)
    grp_mode = (
        data.groupby("group")["strata"]
        .agg(lambda s: s.value_counts().idxmax())
    )
    grp_mode = grp_mode.sample(frac=1.0, random_state=random_state)  # shuffle groups

    train_groups, test_groups = [], []
    for s_val, grp_ids in grp_mode.groupby(grp_mode.values):
        g_list = list(grp_ids.index)
        rng.shuffle(g_list)
        n_test = max(1, int(round(test_size * len(g_list))))
        test_groups.extend(g_list[:n_test])
        train_groups.extend(g_list[n_test:])

    train_mask = np.isin(groups_all, train_groups)
    test_mask  = np.isin(groups_all,  test_groups)
    return np.where(train_mask)[0], np.where(test_mask)[0]

# ---- Classes & seeds ----
classes = ["MCI","NCI","AD","AD+"]     # will save AD+ as 'ADplus' in filenames
def safe_cls(c): return c.replace("+","plus").replace(" ","_").replace("/","-")

seeds = [1,2,3,4,5]

# ---- Main loop ----
for seed in seeds:
    tr_idx, te_idx = group_stratified_shuffle_split(
        df_index=np.arange(len(X)),
        strata_all=strata,
        groups_all=groups,
        test_size=0.30,
        random_state=seed,
    )

    X_train, X_test = X.iloc[tr_idx], X.iloc[te_idx]
    y_train_full    = y[tr_idx]
    y_test_full     = y[te_idx]

    print(f"\n[Seed {seed}] Train n={len(tr_idx)} | Test n={len(te_idx)} | "
          f"Groups train={len(np.unique(groups[tr_idx]))} test={len(np.unique(groups[te_idx]))}")

    for cls in classes:
        y_train = (y_train_full == cls).astype(int)
        y_test  = (y_test_full  == cls).astype(int)

        automl = AutoML()
        settings = {
            "time_budget": 100,               # seconds per class; adjust if you want longer searches
            "metric": "roc_auc",
            "task": "classification",
            "eval_method": "cv",
            "estimator_list": ["lgbm"],       # force LightGBM
            "log_file_name": os.path.join(out_dir, f"flaml_seed{seed}_{safe_cls(cls)}.log"),
            "seed": seed,
        }
        automl.fit(X_train=X_train, y_train=y_train, **settings)
        automl.pickle(os.path.join(out_dir, f"seed{seed}_{safe_cls(cls)}_automl.pkl"))

        # Predict proba for positive class
        y_score = automl.predict_proba(X_test)[:, 1]
        auc = roc_auc_score(y_test, y_score) if (y_test.sum() > 0 and y_test.sum() < len(y_test)) else float("nan")
        print(f"  [{cls}] AUC={auc:.3f}")

        # Save per-class CSV for your existing averaging/plotting script
        out_csv = os.path.join(out_dir, f"seed{seed}_{safe_cls(cls)}.csv")
        pd.DataFrame({"y_true": y_test.astype(int), "y_score": y_score.astype(float)}).to_csv(out_csv, index=False)
# Out:
# [Seed 1] Train n=670 | Test n=283 | Groups train=610 test=261
# [flaml.automl.logger: 08-31 22:20:33] {1752} INFO - task = classification
# [flaml.automl.logger: 08-31 22:20:33] {1763} INFO - Evaluation method: cv
# [flaml.automl.logger: 08-31 22:20:33] {1862} INFO - Minimizing error metric: 1-roc_auc
# [flaml.automl.logger: 08-31 22:20:33] {1979} INFO - List of ML learners in AutoML Run: ['lgbm']
# [flaml.automl.logger: 08-31 22:20:33] {2282} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 08-31 22:20:35] {2417} INFO - Estimated sufficient time budget=19592s. Estimated necessary time budget=20s.
# [flaml.automl.logger: 08-31 22:20:35] {2466} INFO -  at 3.7s,	estimator lgbm's best error=0.3928,	best estimator lgbm's best error=0.3928
# [flaml.automl.logger: 08-31 22:20:35] {2282} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 08-31 22:20:37] {2466} INFO -  at 5.6s,	estimator lgbm's best error=0.3928,	best estimator lgbm's best error=0.3928
# [flaml.automl.logger: 08-31 22:20:37] {2282} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 08-31 22:20:39] {2466} INFO -  at 7.5s,	estimator lgbm's best error=0.3928,	best estimator lgbm's best error=0.3928
# [flaml.automl.logger: 08-31 22:20:39] {2282} INFO - iteration 3, current learner lgbm
# [flaml.automl.logger: 08-31 22:20:41] {2466} INFO -  at 9.4s,	estimator lgbm's best error=0.3928,	best estimator lgbm's best error=0.3928
# [flaml.automl.logger: 08-31 22:20:41] {2282} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 08-31 22:20:43] {2466} INFO -  at 11.5s,	estimator lgbm's best error=0.3928,	best estimator lgbm's best error=0.3928
# [flaml.automl.logger: 08-31 22:20:43] {2282} INFO - iteration 5, current learner lgbm
# [flaml.automl.logger: 08-31 22:20:45] {2466} INFO -  at 13.5s,	estimator lgbm's best error=0.3928,	best estimator lgbm's best error=0.3928
# [flaml.automl.logger: 08-31 22:20:45] {2282} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 08-31 22:20:47] {2466} INFO -  at 15.4s,	estimator lgbm's best error=0.3928,	best estimator lgbm's best error=0.3928
# [flaml.automl.logger: 08-31 22:20:47] {2282} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 08-31 22:20:48] {2466} INFO -  at 17.2s,	estimator lgbm's best error=0.3928,	best estimator lgbm's best error=0.3928
# [flaml.automl.logger: 08-31 22:20:48] {2282} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 08-31 22:20:50] {2466} INFO -  at 19.1s,	estimator lgbm's best error=0.3928,	best estimator lgbm's best error=0.3928
# [flaml.automl.logger: 08-31 22:20:50] {2282} INFO - iteration 9, current learner lgbm
# [flaml.automl.logger: 08-31 22:20:52] {2466} INFO -  at 21.0s,	estimator lgbm's best error=0.3928,	best estimator lgbm's best error=0.3928
# [flaml.automl.logger: 08-31 22:20:52] {2282} INFO - iteration 10, current learner lgbm
# [flaml.automl.logger: 08-31 22:20:54] {2466} INFO -  at 23.2s,	estimator lgbm's best error=0.3928,	best estimator lgbm's best error=0.3928
# [flaml.automl.logger: 08-31 22:20:54] {2282} INFO - iteration 11, current learner lgbm
# [flaml.automl.logger: 08-31 22:20:56] {2466} INFO -  at 25.1s,	estimator lgbm's best error=0.3928,	best estimator lgbm's best error=0.3928
# [flaml.automl.logger: 08-31 22:20:56] {2282} INFO - iteration 12, current learner lgbm
# [flaml.automl.logger: 08-31 22:20:58] {2466} INFO -  at 26.9s,	estimator lgbm's best error=0.3928,	best estimator lgbm's best error=0.3928
# [flaml.automl.logger: 08-31 22:20:58] {2282} INFO - iteration 13, current learner lgbm
# [flaml.automl.logger: 08-31 22:21:00] {2466} INFO -  at 28.6s,	estimator lgbm's best error=0.3928,	best estimator lgbm's best error=0.3928
# [flaml.automl.logger: 08-31 22:21:00] {2282} INFO - iteration 14, current learner lgbm
# [flaml.automl.logger: 08-31 22:21:02] {2466} INFO -  at 30.5s,	estimator lgbm's best error=0.3928,	best estimator lgbm's best error=0.3928
# [flaml.automl.logger: 08-31 22:21:02] {2282} INFO - iteration 15, current learner lgbm
# [flaml.automl.logger: 08-31 22:21:04] {2466} INFO -  at 32.4s,	estimator lgbm's best error=0.3928,	best estimator lgbm's best error=0.3928
# [flaml.automl.logger: 08-31 22:21:04] {2282} INFO - iteration 16, current learner lgbm
# [flaml.automl.logger: 08-31 22:21:05] {2466} INFO -  at 34.2s,	estimator lgbm's best error=0.3928,	best estimator lgbm's best error=0.3928
# [flaml.automl.logger: 08-31 22:21:05] {2282} INFO - iteration 17, current learner lgbm
# [flaml.automl.logger: 08-31 22:21:07] {2466} INFO -  at 36.0s,	estimator lgbm's best error=0.3928,	best estimator lgbm's best error=0.3928
# [flaml.automl.logger: 08-31 22:21:07] {2282} INFO - iteration 18, current learner lgbm
# [flaml.automl.logger: 08-31 22:21:09] {2466} INFO -  at 38.0s,	estimator lgbm's best error=0.3928,	best estimator lgbm's best error=0.3928
# [flaml.automl.logger: 08-31 22:21:09] {2282} INFO - iteration 19, current learner lgbm
# [flaml.automl.logger: 08-31 22:21:11] {2466} INFO -  at 39.6s,	estimator lgbm's best error=0.3928,	best estimator lgbm's best error=0.3928
# [flaml.automl.logger: 08-31 22:21:11] {2282} INFO - iteration 20, current learner lgbm
# [flaml.automl.logger: 08-31 22:21:13] {2466} INFO -  at 41.5s,	estimator lgbm's best error=0.3928,	best estimator lgbm's best error=0.3928
# [flaml.automl.logger: 08-31 22:21:13] {2282} INFO - iteration 21, current learner lgbm
# [flaml.automl.logger: 08-31 22:21:15] {2466} INFO -  at 43.3s,	estimator lgbm's best error=0.3855,	best estimator lgbm's best error=0.3855
# [flaml.automl.logger: 08-31 22:21:15] {2282} INFO - iteration 22, current learner lgbm
# [flaml.automl.logger: 08-31 22:21:16] {2466} INFO -  at 45.1s,	estimator lgbm's best error=0.3855,	best estimator lgbm's best error=0.3855
# [flaml.automl.logger: 08-31 22:21:16] {2282} INFO - iteration 23, current learner lgbm
# [flaml.automl.logger: 08-31 22:21:18] {2466} INFO -  at 47.0s,	estimator lgbm's best error=0.3855,	best estimator lgbm's best error=0.3855
# [flaml.automl.logger: 08-31 22:21:18] {2282} INFO - iteration 24, current learner lgbm
# [flaml.automl.logger: 08-31 22:21
{2282} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 08-31 22:22:18] {2466} INFO -  at 7.5s,	estimator lgbm's best error=0.4090,	best estimator lgbm's best error=0.4090
# [flaml.automl.logger: 08-31 22:22:18] {2282} INFO - iteration 3, current learner lgbm
# [flaml.automl.logger: 08-31 22:22:20] {2466} INFO -  at 9.4s,	estimator lgbm's best error=0.4090,	best estimator lgbm's best error=0.4090
# [flaml.automl.logger: 08-31 22:22:20] {2282} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 08-31 22:22:22] {2466} INFO -  at 11.4s,	estimator lgbm's best error=0.4050,	best estimator lgbm's best error=0.4050
# [flaml.automl.logger: 08-31 22:22:22] {2282} INFO - iteration 5, current learner lgbm
# [flaml.automl.logger: 08-31 22:22:24] {2466} INFO -  at 13.7s,	estimator lgbm's best error=0.3819,	best estimator lgbm's best error=0.3819
# [flaml.automl.logger: 08-31 22:22:24] {2282} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 08-31 22:22:26] {2466} INFO -  at 15.6s,	estimator lgbm's best error=0.3819,	best estimator lgbm's best error=0.3819
# [flaml.automl.logger: 08-31 22:22:26] {2282} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 08-31 22:22:29] {2466} INFO -  at 18.4s,	estimator lgbm's best error=0.3656,	best estimator lgbm's best error=0.3656
# [flaml.automl.logger: 08-31 22:22:29] {2282} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 08-31 22:22:31] {2466} INFO -  at 20.7s,	estimator lgbm's best error=0.3656,	best estimator lgbm's best error=0.3656
# [flaml.automl.logger: 08-31 22:22:31] {2282} INFO - iteration 9, current learner lgbm
# [flaml.automl.logger: 08-31 22:22:36] {2466} INFO -  at 25.6s,	estimator lgbm's best error=0.3603,	best estimator lgbm's best error=0.3603
# [flaml.automl.logger: 08-31 22:22:36] {2282} INFO - iteration 10, current learner lgbm
# [flaml.automl.logger: 08-31 22:22:42] {2466} INFO -  at 32.0s,	estimator lgbm's best error=0.3603,	best estimator lgbm's best error=0.3603
# [flaml.automl.logger: 08-31 22:22:42] {2282} INFO - iteration 11, current learner lgbm
# [flaml.automl.logger: 08-31 22:22:47] {2466} INFO -  at 36.1s,	estimator lgbm's best error=0.3603,	best estimator lgbm's best error=0.3603
# [flaml.automl.logger: 08-31 22:22:47] {2282} INFO - iteration 12, current learner lgbm
# [flaml.automl.logger: 08-31 22:22:50] {2466} INFO -  at 39.8s,	estimator lgbm's best error=0.3603,	best estimator lgbm's best error=0.3603
# [flaml.automl.logger: 08-31 22:22:50] {2282} INFO - iteration 13, current learner lgbm
# [flaml.automl.logger: 08-31 22:22:58] {2466} INFO -  at 47.4s,	estimator lgbm's best error=0.3567,	best estimator lgbm's best error=0.3567
# [flaml.automl.logger: 08-31 22:22:58] {2282} INFO - iteration 14, current learner lgbm
# [flaml.automl.logger: 08-31 22:23:05] {2466} INFO -  at 54.8s,	estimator lgbm's best error=0.3567,	best estimator lgbm's best error=0.3567
# [flaml.automl.logger: 08-31 22:23:05] {2282} INFO - iteration 15, current learner lgbm
# [flaml.automl.logger: 08-31 22:23:13] {2466} INFO -  at 62.9s,	estimator lgbm's best error=0.3567,	best estimator lgbm's best error=0.3567
# [flaml.automl.logger: 08-31 22:23:13] {2282} INFO - iteration 16, current learner lgbm
# [flaml.automl.logger: 08-31 22:23:18] {2466} INFO -  at 67.1s,	estimator lgbm's best error=0.3567,	best estimator lgbm's best error=0.3567
# [flaml.automl.logger: 08-31 22:23:18] {2282} INFO - iteration 17, current learner lgbm
# [flaml.automl.logger: 08-31 22:23:32] {2466} INFO -  at 81.7s,	estimator lgbm's best error=0.3362,	best estimator lgbm's best error=0.3362
# [flaml.automl.logger: 08-31 22:23:32] {2282} INFO - iteration 18, current learner lgbm
# [flaml.automl.logger: 08-31 22:23:39] {2466} INFO -  at 88.3s,	estimator lgbm's best error=0.3362,	best estimator lgbm's best error=0.3362
# [flaml.automl.logger: 08-31 22:23:42] {2724} INFO - retrain lgbm for 3.5s
# [flaml.automl.logger: 08-31 22:23:42] {2727} INFO - retrained model: LGBMClassifier(colsample_bytree=0.9299887434968495,
#                learning_rate=0.19452529005612904, max_bin=127,
#                min_child_samples=4, n_estimators=131, n_jobs=-1, num_leaves=14,
#                reg_alpha=0.0023332860665264167, reg_lambda=0.0009765625,
#                verbose=-1)
# [flaml.automl.logger: 08-31 22:23:42] {2009} INFO - fit succeeded
# [flaml.automl.logger: 08-31 22:23:42] {2010} INFO - Time taken to find the best model: 81.73539614677429
#   [NCI] AUC=0.730
# [flaml.automl.logger: 08-31 22:23:44] {1752} INFO - task = classification
# [flaml.automl.logger: 08-31 22:23:44] {1763} INFO - Evaluation method: cv
# [flaml.automl.logger: 08-31 22:23:44] {1862} INFO - Minimizing error metric: 1-roc_auc
# [flaml.automl.logger: 08-31 22:23:44] {1979} INFO - List of ML learners in AutoML Run: ['lgbm']
# [flaml.automl.logger: 08-31 22:23:44] {2282} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 08-31 22:23:46] {2417} INFO - Estimated sufficient time budget=17956s. Estimated necessary time budget=18s.
# [flaml.automl.logger: 08-31 22:23:46] {2466} INFO -  at 3.5s,	estimator lgbm's best error=0.3226,	best estimator lgbm's best error=0.3226
# [flaml.automl.logger: 08-31 22:23:46] {2282} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 08-31 22:23:48] {2466} INFO -  at 5.3s,	estimator lgbm's best error=0.3226,	best estimator lgbm's best error=0.3226
# [flaml.automl.logger: 08-31 22:23:48] {2282} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 08-31 22:23:50] {2466} INFO -  at 7.2s,	estimator lgbm's best error=0.3150,	best estimator lgbm's best error=0.3150
# [flaml.automl.logger: 08-31 22:23:50] {2282} INFO - iteration 3, current learner lgbm
# [flaml.automl.logger: 08-31 22:23:52] {2466} INFO -  at 9.2s,	estimator lgbm's best error=0.3150,	best estimator lgbm's best error=0.3150
# [flaml.automl.logger: 08-31 22:23:52] {2282} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 08-31 22:23:54] {2466} INFO -  at 11.3s,	estimator lgbm's best error=0.3150,	best estimator lgbm's best error=0.3150
# [flaml.automl.logger: 08-31 22:23:54] {2282} INFO - iteration 5, current learner lgbm
# [flaml.automl.logger: 08-31 22:23:56] {2466} INFO -  at 13.4s,	estimator lgbm's best error=0.3150,	best estimator lgbm's best error=0.3150
# [flaml.automl.logger: 08-31 22:23:56] {2282} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 08-31 22:23:58] {2466} INFO -  at 15.2s,	estimator lgbm's best error=0.3150,	best estimator lgbm's best error=0.3150
# [flaml.automl.logger: 08-31 22:23:58] {2282} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 08-31 22:24:00] {2466} INFO -  at 17.1s,	estimator lgbm's best error=0.3150,	best estimator lgbm's best error=0.3150
# [flaml.automl.logger: 08-31 22:24:00] {2282} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 08-31 22:24:02] {2466} INFO -  at 19.0s,	estimator lgbm's best error=0.3142,	best estimator lgbm's best error=0.3142
# [flaml.automl.logger: 08-31 22:24:02] {2282} INFO - iteration 9, current learner lgbm
# [flaml.automl.logger: 08-31 22:24:03] {2466} INFO -  at 20.7s,	estimator lgbm's best error=0.3142,	best estimator lgbm's best error=0.3142
# [flaml.automl.logger: 08-31 22:24:03] {2282} INFO - iteration 10, current learner lgbm
# [flaml.automl.logger: 08-31 22:24:06] {2466} INFO -  at 22.9s,	estimator lgbm's best error=0.2997,	best estimator lgbm's best error=0.2997
# [flaml.automl.logger: 08-31 22:24:06] {2282} INFO - iteration 11, current learner lgbm
# [flaml.automl.logger: 08-31 22:24:08] {2466} INFO -  at 25.4s,	estimator lgbm's best error=0.2977,	best estimator lgbm's best error=0.2977
# [flaml.automl.logger: 08-31 22:24:08] {2282} INFO - iteration 12, current learner lgbm
# [flaml.automl.logger: 08-31 22:24:10] {2466} INFO -  at 27.6s,	estimator lgbm's best error=0.2977,	best estimator lgbm's best error=0.2977
# [flaml.automl.logger: 08-31 22:24:10] {2282} INFO - iteration 13, current learner lgbm
# [flaml.automl.logger: 08-31 22:24:12] {2466} INFO -  at 29.6s,	estimator lgbm's best error=0.2977,	best estimator lgbm's best error=0.2977
# [flaml.automl.logger: 08-31 22:24:12] {2282} INFO - iteration 14, current learner lgbm
# [flaml.automl.logger: 08-31 22:24:16] {2466} INFO -  at 33.5s,	estimator lgbm's best error=0.2840,	best estimator lgbm's best error=0.2840
# [flaml.automl.logger: 08-31 22:24:16] {2282} INFO - iteration 15, current learner lgbm
# [flaml.automl.logger: 08-31 22:24:19] {2466} INFO -  at 36.5s,	estimator lgbm's best error=0.2840,	best estimator lgbm's best error=0.2840
# [flaml.automl.logger: 08-31 22:24:19] {2282} INFO - iteration 16, current learner lgbm
# [flaml.automl.logger: 08-31 22:24:22] {2466} INFO -  at 39.7s,	estimator lgbm's best error=0.2840,	best estimator lgbm's best error=0.2840
# [flaml.automl.logger: 08-31 22:24:22] {2282} INFO - iteration 17, current learner lgbm
# [flaml.automl.logger: 08-31 22:24:25] {2466} INFO -  at 42.1s,	estimator lgbm's best error=0.2840,	best estimator lgbm's best error=0.2840
# [flaml.automl.logger: 08-31 22:24:25] {2282} INFO - iteration 18, current learner lgbm
# [flaml.automl.logger: 08-31 22:24:31] {2466} INFO -  at 47.9s,	estimator lgbm's best error=0.2345,	best estimator lgbm's best error=0.2345
# [flaml.automl.logger: 08-31 22:24:31] {2282} INFO - iteration 19, current learner lgbm
# [flaml.automl.logger: 08-31 22:24:34] {2466} INFO -  at 51.4s,	estimator lgbm's best error=0.2345,	best estimator lgbm's best error=0.2345
# [flaml.automl.logger: 08-31 22:24:34] {2282} INFO - iteration 20, current learner lgbm
# [flaml.automl.logger: 08-31 22:24:41] {2466} INFO -  at 58.7s,	estimator lgbm's best error=0.2345,	best estimator lgbm's best error=0.2345
# [flaml.automl.logger: 08-31 22:24:41] {2282} INFO - iteration 21, current learner lgbm
# [flaml.automl.logger: 08-31 22:24:44] {2466} INFO -  at 61.8s,	estimator lgbm's best error=0.2345,	best estimator lgbm's best error=0.2345
# [flaml.automl.logger: 08-31 22:24:44] {2282} INFO - iteration 22, current learner lgbm
# [flaml.automl.logger: 08-31 22:24:51] {2466} INFO -  at 68.3s,	estimator lgbm's best error=0.2345,	best estimator lgbm's best error=0.2345
# [flaml.automl.logger: 08-31 22:24:51] {2282} INFO - iteration 23, current learner lgbm
# [flaml.automl.logger: 08-31 22:24:56] {2466} INFO -  at 73.3s,	estimator lgbm's best error=0.2345,	best estimator lgbm's best error=0.2345
# [flaml.automl.logger: 08-31 22:24:56] {2282} INFO - iteration 24, current learner lgbm
# [flaml.automl.logger: 08-31 22:25:01] {2466} INFO -  at 78.5s,	estimator lgbm's best error=0.2299,	best estimator lgbm's best error=0.2299
# [flaml.automl.logger: 08-31 22:25:01] {2282} INFO - iteration 25, current learner lgbm
# [flaml.automl.logger: 08-31 22:25:08] {2466} INFO -  at 85.4s,	estimator lgbm's best error=0.2299,	best estimator lgbm's best error=0.2299
# [flaml.automl.logger: 08-31 22:25:08] {2282} INFO - iteration 26, current learner lgbm
# [flaml.automl.logger: 08-31 22:25:12] {2466} INFO -  at 88.8s,	estimator lgbm's best error=0.2299,	best estimator lgbm's best error=0.2299
# [flaml.automl.logger: 08-31 22:25:12] {2282} INFO - iteration 27, current learner lgbm
# [flaml.automl.logger: 08-31 22:25:17] {2466} INFO -  at 94.1s,	estimator lgbm's best error=0.2299,	best estimator lgbm's best error=0.2299
# [flaml.automl.logger: 08-31 22:25:17] {2282} INFO - iteration 28, current learner lgbm
# [flaml.automl.logger: 08-31 22:25:22] {2466} INFO -  at 99.4s,	estimator lgbm's best error=0.2299,	best estimator lgbm's best error=0.2299
# [flaml.automl.logger: 08-31 22:25:23] {2724} INFO - retrain lgbm for 1.0s
# [flaml.automl.logger: 08-31 22:25:23] {2727} INFO - retrained model: LGBMClassifier(colsample_bytree=0.7610240209128091,
#                learning_rate=0.2745907066816591, max_bin=511,
#                min_child_samples=13, n_estimators=106, n_jobs=-1, num_leaves=5,
#                reg_alpha=0.039666434362235506, reg_lambda=0.0009765625,
#                verbose=-1)
# [flaml.automl.logger: 08-31 22:25:23] {2009} INFO - fit succeeded
# [flaml.automl.logger: 08-31 22:25:23] {2010} INFO - Time taken to find the best model: 78.53455400466919
#   [AD] AUC=0.746
# [flaml.automl.logger: 08-31 22:25:25] {1752} INFO - task = classification
# [flaml.automl.logger: 08-31 22:25:25] {1763} INFO - Evaluation method: cv
# [flaml.automl.logger: 08-31 22:25:25] {1862} INFO - Minimizing error metric: 1-roc_auc
# [flaml.automl.logger: 08-31 22:25:25] {1979} INFO - List of ML learners in AutoML Run: ['lgbm']
# [flaml.automl.logger: 08-31 22:25:25] {2282} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 08-31 22:25:27] {2417} INFO - Estimated sufficient time budget=18026s. Estimated necessary time budget=18s.
# [flaml.automl.logger: 08-31 22:25:27] {2466} INFO -  at 3.5s,	estimator lgbm's best error=0.1483,	best estimator lgbm's best error=0.1483
# [flaml.automl.logger: 08-31 22:25:27] {2282} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 08-31 22:25:29] {2466} INFO -  at 5.3s,	estimator lgbm's best error=0.1367,	best estimator lgbm's best error=0.1367
# [flaml.automl.logger: 08-31 22:25:29] {2282} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 08-31 22:25:31] {2466} INFO -  at 7.2s,	estimator lgbm's best error=0.1191,	best estimator lgbm's best error=0.1191
# [flaml.automl.logger: 08-31 22:25:31] {2282} INFO - iteration 3, current learner lgbm
# [flaml.automl.logger: 08-31 22:25:33] {2466} INFO -  at 9.1s,	estimator lgbm's best error=0.0787,	best estimator lgbm's best error=0.0787
# [flaml.automl.logger: 08-31 22:25:33] {2282} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 08-31 22:25:35] {2466} INFO -  at 11.1s,	estimator lgbm's best error=0.0787,	best estimator lgbm's best error=0.0787
# [flaml.automl.logger: 08-31 22:25:35] {2282} INFO - iteration 5, current learner lgbm
# [flaml.automl.logger: 08-31 22:25:37] {2466} INFO -  at 13.0s,	estimator lgbm's best error=0.0787,	best estimator lgbm's best error=0.0787
# [flaml.automl.logger: 08-31 22:25:37] {2282} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 08-31 22:25:38] {2466} INFO -  at 14.9s,	estimator lgbm's best error=0.0787,	best estimator lgbm's best error=0.0787
# [flaml.automl.logger: 08-31 22:25:38] {2282} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 08-31 22:25:40] {2466} INFO -  at 16.8s,	estimator lgbm's best error=0.0787,	best estimator lgbm's best error=0.0787
# [flaml.automl.logger: 08-31 22:25:40] {2282} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 08-31 22:25:42] {2466} INFO -  at 18.7s,	estimator lgbm's best error=0.0787,	best estimator lgbm's best error=0.0787
# [flaml.automl.logger: 08-31 22:25:42] {2282} INFO - iteration 9, current learner lgbm
# [flaml.automl.logger: 08-31 22:25
{1763} INFO - Evaluation method: cv
# [flaml.automl.logger: 08-31 22:27:05] {1862} INFO - Minimizing error metric: 1-roc_auc
# [flaml.automl.logger: 08-31 22:27:05] {1979} INFO - List of ML learners in AutoML Run: ['lgbm']
# [flaml.automl.logger: 08-31 22:27:05] {2282} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 08-31 22:27:06] {2417} INFO - Estimated sufficient time budget=19851s. Estimated necessary time budget=20s.
# [flaml.automl.logger: 08-31 22:27:06] {2466} INFO -  at 3.8s,	estimator lgbm's best error=0.4595,	best estimator lgbm's best error=0.4595
# [flaml.automl.logger: 08-31 22:27:07] {2282} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 08-31 22:27:09] {2466} INFO -  at 5.9s,	estimator lgbm's best error=0.4461,	best estimator lgbm's best error=0.4461
# [flaml.automl.logger: 08-31 22:27:09] {2282} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 08-31 22:27:11] {2466} INFO -  at 7.9s,	estimator lgbm's best error=0.4461,	best estimator lgbm's best error=0.4461
# [flaml.automl.logger: 08-31 22:27:11] {2282} INFO - iteration 3, current learner lgbm
# [flaml.automl.logger: 08-31 22:27:13] {2466} INFO -  at 10.1s,	estimator lgbm's best error=0.4461,	best estimator lgbm's best error=0.4461
# [flaml.automl.logger: 08-31 22:27:13] {2282} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 08-31 22:27:15] {2466} INFO -  at 12.2s,	estimator lgbm's best error=0.4461,	best estimator lgbm's best error=0.4461
# [flaml.automl.logger: 08-31 22:27:15] {2282} INFO - iteration 5, current learner lgbm
# [flaml.automl.logger: 08-31 22:27:17] {2466} INFO -  at 14.1s,	estimator lgbm's best error=0.4461,	best estimator lgbm's best error=0.4461
# [flaml.automl.logger: 08-31 22:27:17] {2282} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 08-31 22:27:20] {2466} INFO -  at 17.2s,	estimator lgbm's best error=0.4461,	best estimator lgbm's best error=0.4461
# [flaml.automl.logger: 08-31 22:27:20] {2282} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 08-31 22:27:22] {2466} INFO -  at 19.1s,	estimator lgbm's best error=0.4461,	best estimator lgbm's best error=0.4461
# [flaml.automl.logger: 08-31 22:27:22] {2282} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 08-31 22:27:25] {2466} INFO -  at 22.0s,	estimator lgbm's best error=0.4461,	best estimator lgbm's best error=0.4461
# [flaml.automl.logger: 08-31 22:27:25] {2282} INFO - iteration 9, current learner lgbm
# [flaml.automl.logger: 08-31 22:27:27] {2466} INFO -  at 23.8s,	estimator lgbm's best error=0.4461,	best estimator lgbm's best error=0.4461
# [flaml.automl.logger: 08-31 22:27:27] {2282} INFO - iteration 10, current learner lgbm
# [flaml.automl.logger: 08-31 22:27:29] {2466} INFO -  at 26.6s,	estimator lgbm's best error=0.4461,	best estimator lgbm's best error=0.4461
# [flaml.automl.logger: 08-31 22:27:29] {2282} INFO - iteration 11, current learner lgbm
# [flaml.automl.logger: 08-31 22:27:31] {2466} INFO -  at 28.6s,	estimator lgbm's best error=0.4461,	best estimator lgbm's best error=0.4461
# [flaml.automl.logger: 08-31 22:27:31] {2282} INFO - iteration 12, current learner lgbm
# [flaml.automl.logger: 08-31 22:27:34] {2466} INFO -  at 31.0s,	estimator lgbm's best error=0.4461,	best estimator lgbm's best error=0.4461
# [flaml.automl.logger: 08-31 22:27:34] {2282} INFO - iteration 13, current learner lgbm
# [flaml.automl.logger: 08-31 22:27:36] {2466} INFO -  at 32.9s,	estimator lgbm's best error=0.4461,	best estimator lgbm's best error=0.4461
# [flaml.automl.logger: 08-31 22:27:36] {2282} INFO - iteration 14, current learner lgbm
# [flaml.automl.logger: 08-31 22:27:39] {2466} INFO -  at 35.8s,	estimator lgbm's best error=0.4403,	best estimator lgbm's best error=0.4403
# [flaml.automl.logger: 08-31 22:27:39] {2282} INFO - iteration 15, current learner lgbm
# [flaml.automl.logger: 08-31 22:27:41] {2466} INFO -  at 38.7s,	estimator lgbm's best error=0.4403,	best estimator lgbm's best error=0.4403
# [flaml.automl.logger: 08-31 22:27:41] {2282} INFO - iteration 16, current learner lgbm
# [flaml.automl.logger: 08-31 22:27:44] {2466} INFO -  at 41.6s,	estimator lgbm's best error=0.4403,	best estimator lgbm's best error=0.4403
# [flaml.automl.logger: 08-31 22:27:44] {2282} INFO - iteration 17, current learner lgbm
# [flaml.automl.logger: 08-31 22:27:47] {2466} INFO -  at 44.0s,	estimator lgbm's best error=0.4403,	best estimator lgbm's best error=0.4403
# [flaml.automl.logger: 08-31 22:27:47] {2282} INFO - iteration 18, current learner lgbm
# [flaml.automl.logger: 08-31 22:27:50] {2466} INFO -  at 47.1s,	estimator lgbm's best error=0.4394,	best estimator lgbm's best error=0.4394
# [flaml.automl.logger: 08-31 22:27:50] {2282} INFO - iteration 19, current learner lgbm
# [flaml.automl.logger: 08-31 22:27:54] {2466} INFO -  at 51.4s,	estimator lgbm's best error=0.4391,	best estimator lgbm's best error=0.4391
# [flaml.automl.logger: 08-31 22:27:54] {2282} INFO - iteration 20, current learner lgbm
# [flaml.automl.logger: 08-31 22:27:57] {2466} INFO -  at 54.7s,	estimator lgbm's best error=0.4391,	best estimator lgbm's best error=0.4391
# [flaml.automl.logger: 08-31 22:27:57] {2282} INFO - iteration 21, current learner lgbm
# [flaml.automl.logger: 08-31 22:28:00] {2466} INFO -  at 57.7s,	estimator lgbm's best error=0.4391,	best estimator lgbm's best error=0.4391
# [flaml.automl.logger: 08-31 22:28:00] {2282} INFO - iteration 22, current learner lgbm
# [flaml.automl.logger: 08-31 22:28:07] {2466} INFO -  at 64.5s,	estimator lgbm's best error=0.4346,	best estimator lgbm's best error=0.4346
# [flaml.automl.logger: 08-31 22:28:07] {2282} INFO - iteration 23, current learner lgbm
# [flaml.automl.logger: 08-31 22:28:10] {2466} INFO -  at 67.3s,	estimator lgbm's best error=0.4346,	best estimator lgbm's best error=0.4346
# [flaml.automl.logger: 08-31 22:28:10] {2282} INFO - iteration 24, current learner lgbm
# [flaml.automl.logger: 08-31 22:28:28] {2466} INFO -  at 85.3s,	estimator lgbm's best error=0.4346,	best estimator lgbm's best error=0.4346
# [flaml.automl.logger: 08-31 22:28:28] {2282} INFO - iteration 25, current learner lgbm
# [flaml.automl.logger: 08-31 22:28:33] {2466} INFO -  at 89.9s,	estimator lgbm's best error=0.4200,	best estimator lgbm's best error=0.4200
# [flaml.automl.logger: 08-31 22:28:33] {2282} INFO - iteration 26, current learner lgbm
# [flaml.automl.logger: 08-31 22:28:40] {2466} INFO -  at 97.0s,	estimator lgbm's best error=0.4189,	best estimator lgbm's best error=0.4189
# [flaml.automl.logger: 08-31 22:28:41] {2724} INFO - retrain lgbm for 1.7s
# [flaml.automl.logger: 08-31 22:28:41] {2727} INFO - retrained model: LGBMClassifier(colsample_bytree=0.5579479967490696,
#                learning_rate=0.11564045696289445, max_bin=255,
#                min_child_samples=12, n_estimators=79, n_jobs=-1, num_leaves=14,
#                reg_alpha=0.0010857463243656043, reg_lambda=11.786837824575006,
#                verbose=-1)
# [flaml.automl.logger: 08-31 22:28:41] {2009} INFO - fit succeeded
# [flaml.automl.logger: 08-31 22:28:41] {2010} INFO - Time taken to find the best model: 96.96284317970276
#   [MCI] AUC=0.509
# [flaml.automl.logger: 08-31 22:28:43] {1752} INFO - task = classification
# [flaml.automl.logger: 08-31 22:28:43] {1763} INFO - Evaluation method: cv
# [flaml.automl.logger: 08-31 22:28:44] {1862} INFO - Minimizing error metric: 1-roc_auc
# [flaml.automl.logger: 08-31 22:28:44] {1979} INFO - List of ML learners in AutoML Run: ['lgbm']
# [flaml.automl.logger: 08-31 22:28:44] {2282} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 08-31 22:28:45] {2417} INFO - Estimated sufficient time budget=18528s. Estimated necessary time budget=19s.
# [flaml.automl.logger: 08-31 22:28:45] {2466} INFO -  at 3.6s,	estimator lgbm's best error=0.3690,	best estimator lgbm's best error=0.3690
# [flaml.automl.logger: 08-31 22:28:45] {2282} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 08-31 22:28:48] {2466} INFO -  at 5.7s,	estimator lgbm's best error=0.3690,	best estimator lgbm's best error=0.3690
# [flaml.automl.logger: 08-31 22:28:48] {2282} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 08-31 22:28:50] {2466} INFO -  at 7.7s,	estimator lgbm's best error=0.3639,	best estimator lgbm's best error=0.3639
# [flaml.automl.logger: 08-31 22:28:50] {2282} INFO - iteration 3, current learner lgbm
# [flaml.automl.logger: 08-31 22:28:51] {2466} INFO -  at 9.6s,	estimator lgbm's best error=0.3639,	best estimator lgbm's best error=0.3639
# [flaml.automl.logger: 08-31 22:28:51] {2282} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 08-31 22:28:53] {2466} INFO -  at 11.4s,	estimator lgbm's best error=0.3630,	best estimator lgbm's best error=0.3630
# [flaml.automl.logger: 08-31 22:28:53] {2282} INFO - iteration 5, current learner lgbm
# [flaml.automl.logger: 08-31 22:28:55] {2466} INFO -  at 13.1s,	estimator lgbm's best error=0.3630,	best estimator lgbm's best error=0.3630
# [flaml.automl.logger: 08-31 22:28:55] {2282} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 08-31 22:28:57] {2466} INFO -  at 15.1s,	estimator lgbm's best error=0.3630,	best estimator lgbm's best error=0.3630
# [flaml.automl.logger: 08-31 22:28:57] {2282} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 08-31 22:28:59] {2466} INFO -  at 16.8s,	estimator lgbm's best error=0.3611,	best estimator lgbm's best error=0.3611
# [flaml.automl.logger: 08-31 22:28:59] {2282} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 08-31 22:29:01] {2466} INFO -  at 18.8s,	estimator lgbm's best error=0.3557,	best estimator lgbm's best error=0.3557
# [flaml.automl.logger: 08-31 22:29:01] {2282} INFO - iteration 9, current learner lgbm
# [flaml.automl.logger: 08-31 22:29:02] {2466} INFO -  at 20.5s,	estimator lgbm's best error=0.3557,	best estimator lgbm's best error=0.3557
# [flaml.automl.logger: 08-31 22:29:02] {2282} INFO - iteration 10, current learner lgbm
# [flaml.automl.logger: 08-31 22:29:05] {2466} INFO -  at 22.8s,	estimator lgbm's best error=0.3557,	best estimator lgbm's best error=0.3557
# ...
# [flaml.automl.logger: 08-31 22:51:16] {2282} INFO - iteration 28, current learner lgbm
# [flaml.automl.logger: 08-31 22:51:18] {2466} INFO -  at 61.1s,	estimator lgbm's best error=0.2377,	best estimator lgbm's best error=0.2377
# [flaml.automl.logger: 08-31 22:51:18] {2282} INFO - iteration 29, current learner lgbm
# [flaml.automl.logger: 08-31 22:51:20] {2466} INFO -  at 63.1s,	estimator lgbm's best error=0.2377,	best estimator lgbm's best error=0.2377
# [flaml.automl.logger: 08-31 22:51:20] {2282} INFO - iteration 30, current learner lgbm
# [flaml.automl.logger: 08-31 22:51:22] {2466} INFO -  at 65.3s,	estimator lgbm's best error=0.2377,	best estimator lgbm's best error=0.2377
# [flaml.automl.logger: 08-31 22:51:22] {2282} INFO - iteration 31, current learner lgbm
# [flaml.automl.logger: 08-31 22:51:24] {2466} INFO -  at 67.4s,	estimator lgbm's best error=0.2374,	best estimator lgbm's best error=0.2374
# [flaml.automl.logger: 08-31 22:51:24] {2282} INFO - iteration 32, current learner lgbm
# [flaml.automl.logger: 08-31 22:51:26] {2466} INFO -  at 69.5s,	estimator lgbm's best error=0.2374,	best estimator lgbm's best error=0.2374
# [flaml.automl.logger: 08-31 22:51:26] {2282} INFO - iteration 33, current learner lgbm
# [flaml.automl.logger: 08-31 22:51:28] {2466} INFO -  at 71.4s,	estimator lgbm's best error=0.2374,	best estimator lgbm's best error=0.2374
# [flaml.automl.logger: 08-31 22:51:28] {2282} INFO - iteration 34, current learner lgbm
# [flaml.automl.logger: 08-31 22:51:30] {2466} INFO -  at 73.5s,	estimator lgbm's best error=0.2374,	best estimator lgbm's best error=0.2374
# [flaml.automl.logger: 08-31 22:51:30] {2282} INFO - iteration 35, current learner lgbm
# [flaml.automl.logger: 08-31 22:51:32] {2466} INFO -  at 75.3s,	estimator lgbm's best error=0.2374,	best estimator lgbm's best error=0.2374
# [flaml.automl.logger: 08-31 22:51:32] {2282} INFO - iteration 36, current learner lgbm
# [flaml.automl.logger: 08-31 22:51:34] {2466} INFO -  at 77.3s,	estimator lgbm's best error=0.2374,	best estimator lgbm's best error=0.2374
# [flaml.automl.logger: 08-31 22:51:34] {2282} INFO - iteration 37, current learner lgbm
# [flaml.automl.logger: 08-31 22:51:36] {2466} INFO -  at 79.3s,	estimator lgbm's best error=0.2374,	best estimator lgbm's best error=0.2374
# [flaml.automl.logger: 08-31 22:51:36] {2282} INFO - iteration 38, current learner lgbm
# [flaml.automl.logger: 08-31 22:51:38] {2466} INFO -  at 81.4s,	estimator lgbm's best error=0.2374,	best estimator lgbm's best error=0.2374
# [flaml.automl.logger: 08-31 22:51:38] {2282} INFO - iteration 39, current learner lgbm
# [flaml.automl.logger: 08-31 22:51:40] {2466} INFO -  at 83.5s,	estimator lgbm's best error=0.2374,	best estimator lgbm's best error=0.2374
# [flaml.automl.logger: 08-31 22:51:40] {2282} INFO - iteration 40, current learner lgbm
# [flaml.automl.logger: 08-31 22:51:42] {2466} INFO -  at 85.5s,	estimator lgbm's best error=0.2374,	best estimator lgbm's best error=0.2374
# [flaml.automl.logger: 08-31 22:51:42] {2282} INFO - iteration 41, current learner lgbm
# [flaml.automl.logger: 08-31 22:51:45] {2466} INFO -  at 87.8s,	estimator lgbm's best error=0.2374,	best estimator lgbm's best error=0.2374
# [flaml.automl.logger: 08-31 22:51:45] {2282} INFO - iteration 42, current learner lgbm
# [flaml.automl.logger: 08-31 22:51:46] {2466} INFO -  at 89.5s,	estimator lgbm's best error=0.2374,	best estimator lgbm's best error=0.2374
# [flaml.automl.logger: 08-31 22:51:46] {2282} INFO - iteration 43, current learner lgbm
# [flaml.automl.logger: 08-31 22:51:48] {2466} INFO -  at 91.5s,	estimator lgbm's best error=0.2374,	best estimator lgbm's best error=0.2374
# [flaml.automl.logger: 08-31 22:51:48] {2282} INFO - iteration 44, current learner lgbm
# [flaml.automl.logger: 08-31 22:51:50] {2466} INFO -  at 93.4s,	estimator lgbm's best error=0.2374,	best estimator lgbm's best error=0.2374
# [flaml.automl.logger: 08-31 22:51:50] {2282} INFO - iteration 45, current learner lgbm
# [flaml.automl.logger: 08-31 22:51:52] {2466} INFO -  at 95.4s,	estimator lgbm's best error=0.2374,	best estimator lgbm's best error=0.2374
# [flaml.automl.logger: 08-31 22:51:52] {2282} INFO - iteration 46, current learner lgbm
# [flaml.automl.logger: 08-31 22:51:54] {2466} INFO -  at 97.6s,	estimator lgbm's best error=0.2374,	best estimator lgbm's best error=0.2374
# [flaml.automl.logger: 08-31 22:51:54] {2282} INFO - iteration 47, current learner lgbm
# [flaml.automl.logger: 08-31 22:51:56] {2466} INFO -  at 99.4s,	estimator lgbm's best error=0.2374,	best estimator lgbm's best error=0.2374
# [flaml.automl.logger: 08-31 22:51:57] {2724} INFO - retrain lgbm for 0.4s
# [flaml.automl.logger: 08-31 22:51:57] {2727} INFO - retrained model: LGBMClassifier(colsample_bytree=0.9304093980306718,
#                learning_rate=0.1769723647480847, max_bin=511,
#                min_child_samples=93, n_estimators=11, n_jobs=-1, num_leaves=4,
#                reg_alpha=0.0009765625, reg_lambda=0.02618329504678367,
#                verbose=-1)
# [flaml.automl.logger: 08-31 22:51:57] {2009} INFO - fit succeeded
# [flaml.automl.logger: 08-31 22:51:57] {2010} INFO - Time taken to find the best model: 67.43388319015503
#   [AD] AUC=0.697
# [flaml.automl.logger: 08-31 22:51:59] {1752} INFO - task = classification
# [flaml.automl.logger: 08-31 22:51:59] {1763} INFO - Evaluation method: cv
# [flaml.automl.logger: 08-31 22:51:59] {1862} INFO - Minimizing error metric: 1-roc_auc
# [flaml.automl.logger: 08-31 22:51:59] {1979} INFO - List of ML learners in AutoML Run: ['lgbm']
# [flaml.automl.logger: 08-31 22:51:59] {2282} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 08-31 22:52:01] {2417} INFO - Estimated sufficient time budget=19293s. Estimated necessary time budget=19s.
# [flaml.automl.logger: 08-31 22:52:01] {2466} INFO -  at 3.8s,	estimator lgbm's best error=0.1202,	best estimator lgbm's best error=0.1202
# [flaml.automl.logger: 08-31 22:52:01] {2282} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 08-31 22:52:03] {2466} INFO -  at 5.6s,	estimator lgbm's best error=0.1202,	best estimator lgbm's best error=0.1202
# [flaml.automl.logger: 08-31 22:52:03] {2282} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 08-31 22:52:05] {2466} INFO -  at 7.5s,	estimator lgbm's best error=0.0557,	best estimator lgbm's best error=0.0557
# [flaml.automl.logger: 08-31 22:52:05] {2282} INFO - iteration 3, current learner lgbm
# [flaml.automl.logger: 08-31 22:52:07] {2466} INFO -  at 9.6s,	estimator lgbm's best error=0.0170,	best estimator lgbm's best error=0.0170
# [flaml.automl.logger: 08-31 22:52:07] {2282} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 08-31 22:52:09] {2466} INFO -  at 11.5s,	estimator lgbm's best error=0.0170,	best estimator lgbm's best error=0.0170
# [flaml.automl.logger: 08-31 22:52:09] {2282} INFO - iteration 5, current learner lgbm
# [flaml.automl.logger: 08-31 22:52:11] {2466} INFO -  at 13.7s,	estimator lgbm's best error=0.0170,	best estimator lgbm's best error=0.0170
# [flaml.automl.logger: 08-31 22:52:11] {2282} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 08-31 22:52:13] {2466} INFO -  at 16.1s,	estimator lgbm's best error=0.0170,	best estimator lgbm's best error=0.0170
# [flaml.automl.logger: 08-31 22:52:13] {2282} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 08-31 22:52:15] {2466} INFO -  at 18.4s,	estimator lgbm's best error=0.0128,	best estimator lgbm's best error=0.0128
# [flaml.automl.logger: 08-31 22:52:15] {2282} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 08-31 22:52:18] {2466} INFO -  at 20.5s,	estimator lgbm's best error=0.0128,	best estimator lgbm's best error=0.0128
# [flaml.automl.logger: 08-31 22:52:18] {2282} INFO - iteration 9, current learner lgbm
# [flaml.automl.logger: 08-31 22:52:20] {2466} INFO -  at 22.9s,	estimator lgbm's best error=0.0024,	best estimator lgbm's best error=0.0024
# [flaml.automl.logger: 08-31 22:52:20] {2282} INFO - iteration 10, current learner lgbm
# [flaml.automl.logger: 08-31 22:52:22] {2466} INFO -  at 25.0s,	estimator lgbm's best error=0.0024,	best estimator lgbm's best error=0.0024
# [flaml.automl.logger: 08-31 22:52:22] {2282} INFO - iteration 11, current learner lgbm
# [flaml.automl.logger: 08-31 22:52:25] {2466} INFO -  at 28.1s,	estimator lgbm's best error=0.0024,	best estimator lgbm's best error=0.0024
# [flaml.automl.logger: 08-31 22:52:25] {2282} INFO - iteration 12, current learner lgbm
# [flaml.automl.logger: 08-31 22:52:27] {2466} INFO -  at 30.2s,	estimator lgbm's best error=0.0024,	best estimator lgbm's best error=0.0024
# [flaml.automl.logger: 08-31 22:52:27] {2282} INFO - iteration 13, current learner lgbm
# [flaml.automl.logger: 08-31 22:52:30] {2466} INFO -  at 32.5s,	estimator lgbm's best error=0.0024,	best estimator lgbm's best error=0.0024
# [flaml.automl.logger: 08-31 22:52:30] {2282} INFO - iteration 14, current learner lgbm
# [flaml.automl.logger: 08-31 22:52:32] {2466} INFO -  at 35.3s,	estimator lgbm's best error=0.0024,	best estimator lgbm's best error=0.0024
# [flaml.automl.logger: 08-31 22:52:32] {2282} INFO - iteration 15, current learner lgbm
# [flaml.automl.logger: 08-31 22:52:36] {2466} INFO -  at 38.6s,	estimator lgbm's best error=0.0024,	best estimator lgbm's best error=0.0024
# [flaml.automl.logger: 08-31 22:52:36] {2282} INFO - iteration 16, current learner lgbm
# [flaml.automl.logger: 08-31 22:52:38] {2466} INFO -  at 40.7s,	estimator lgbm's best error=0.0024,	best estimator lgbm's best error=0.0024
# [flaml.automl.logger: 08-31 22:52:38] {2282} INFO - iteration 17, current learner lgbm
# [flaml.automl.logger: 08-31 22:52:40] {2466} INFO -  at 42.9s,	estimator lgbm's best error=0.0024,	best estimator lgbm's best error=0.0024
# [flaml.automl.logger: 08-31 22:52:40] {2282} INFO - iteration 18, current learner lgbm
# [flaml.automl.logger: 08-31 22:52:42] {2466} INFO -  at 45.2s,	estimator lgbm's best error=0.0024,	best estimator lgbm's best error=0.0024
# [flaml.automl.logger: 08-31 22:52:42] {2282} INFO - iteration 19, current learner lgbm
# [flaml.automl.logger: 08-31 22:52:46] {2466} INFO -  at 48.6s,	estimator lgbm's best error=0.0024,	best estimator lgbm's best error=0.0024
# [flaml.automl.logger: 08-31 22:52:46] {2282} INFO - iteration 20, current learner lgbm
# [flaml.automl.logger: 08-31 22:52:48] {2466} INFO -  at 50.9s,	estimator lgbm's best error=0.0024,	best estimator lgbm's best error=0.0024
# [flaml.automl.logger: 08-31 22:52:48] {2282} INFO - iteration 21, current learner lgbm
# [flaml.automl.logger: 08-31 22:52:51] {2466} INFO -  at 53.6s,	estimator lgbm's best error=0.0024,	best estimator lgbm's best error=0.0024
# [flaml.automl.logger: 08-31 22:52:51] {2282} INFO - iteration 22, current learner lgbm
# [flaml.automl.logger: 08-31 22:52:53] {2466} INFO -  at 55.8s,	estimator lgbm's best error=0.0024,	best estimator lgbm's best error=0.0024
# [flaml.automl.logger: 08-31 22:52:53] {2282} INFO - iteration 23, current learner lgbm
# [flaml.automl.logger: 08-31 22:52:56] {2466} INFO -  at 58.4s,	estimator lgbm's best error=0.0024,	best estimator lgbm's best error=0.0024
# [flaml.automl.logger: 08-31 22:52:56] {2282} INFO - iteration 24, current learner lgbm
# [flaml.automl.logger: 08-31 22:52:58] {2466} INFO -  at 60.6s,	estimator lgbm's best error=0.0024,	best estimator lgbm's best error=0.0024
# [flaml.automl.logger: 08-31 22:52:58] {2282} INFO - iteration 25, current learner lgbm
# [flaml.automl.logger: 08-31 22:53:00] {2466} INFO -  at 63.1s,	estimator lgbm's best error=0.0024,	best estimator lgbm's best error=0.0024
# [flaml.automl.logger: 08-31 22:53:00] {2282} INFO - iteration 26, current learner lgbm
# [flaml.automl.logger: 08-31 22:53:03] {2466} INFO -  at 65.6s,	estimator lgbm's best error=0.0024,	best estimator lgbm's best error=0.0024
# [flaml.automl.logger: 08-31 22:53:03] {2282} INFO - iteration 27, current learner lgbm
# [flaml.automl.logger: 08-31 22:53:05] {2466} INFO -  at 67.6s,	estimator lgbm's best error=0.0024,	best estimator lgbm's best error=0.0024
# [flaml.automl.logger: 08-31 22:53:05] {2282} INFO - iteration 28, current learner lgbm
# [flaml.automl.logger: 08-31 22:53:08] {2466} INFO -  at 71.0s,	estimator lgbm's best error=0.0024,	best estimator lgbm's best error=0.0024
# [flaml.automl.logger: 08-31 22:53:08] {2282} INFO - iteration 29, current learner lgbm
# [flaml.automl.logger: 08-31 22:53:10] {2466} INFO -  at 73.3s,	estimator lgbm's best error=0.0024,	best estimator lgbm's best error=0.0024
# [flaml.automl.logger: 08-31 22:53:10] {2282} INFO - iteration 30, current learner lgbm
# [flaml.automl.logger: 08-31 22:53:12] {2466} INFO -  at 75.3s,	estimator lgbm's best error=0.0024,	best estimator lgbm's best error=0.0024
# [flaml.automl.logger: 08-31 22:53:12] {2282} INFO - iteration 31, current learner lgbm
# [flaml.automl.logger: 08-31 22:53:14] {2466} INFO -  at 77.2s,	estimator lgbm's best error=0.0024,	best estimator lgbm's best error=0.0024
# [flaml.automl.logger: 08-31 22:53:14] {2282} INFO - iteration 32, current learner lgbm
# [flaml.automl.logger: 08-31 22:53:16] {2466} INFO -  at 79.2s,	estimator lgbm's best error=0.0024,	best estimator lgbm's best error=0.0024
# [flaml.automl.logger: 08-31 22:53:16] {2282} INFO - iteration 33, current learner lgbm
# [flaml.automl.logger: 08-31 22:53:18] {2466} INFO -  at 81.0s,	estimator lgbm's best error=0.0024,	best estimator lgbm's best error=0.0024
# [flaml.automl.logger: 08-31 22:53:18] {2282} INFO - iteration 34, current learner lgbm
# [flaml.automl.logger: 08-31 22:53:20] {2466} INFO -  at 83.2s,	estimator lgbm's best error=0.0024,	best estimator lgbm's best error=0.0024
# [flaml.automl.logger: 08-31 22:53:20] {2282} INFO - iteration 35, current learner lgbm
# [flaml.automl.logger: 08-31 22:53:22] {2466} INFO -  at 85.1s,	estimator lgbm's best error=0.0024,	best estimator lgbm's best error=0.0024
# [flaml.automl.logger: 08-31 22:53:22] {2282} INFO - iteration 36, current learner lgbm
# [flaml.automl.logger: 08-31 22:53:24] {2466} INFO -  at 87.1s,	estimator lgbm's best error=0.0024,	best estimator lgbm's best error=0.0024
# [flaml.automl.logger: 08-31 22:53:24] {2282} INFO - iteration 37, current learner lgbm
# [flaml.automl.logger: 08-31 22:53:26] {2466} INFO -  at 89.0s,	estimator lgbm's best error=0.0024,	best estimator lgbm's best error=0.0024
# [flaml.automl.logger: 08-31 22:53:26] {2282} INFO - iteration 38, current learner lgbm
# [flaml.automl.logger: 08-31 22:53:28] {2466} INFO -  at 91.1s,	estimator lgbm's best error=0.0024,	best estimator lgbm's best error=0.0024
# [flaml.automl.logger: 08-31 22:53:28] {2282} INFO - iteration 39, current learner lgbm
# [flaml.automl.logger: 08-31 22:53:30] {2466} INFO -  at 93.3s,	estimator lgbm's best error=0.0024,	best estimator lgbm's best error=0.0024
# [flaml.automl.logger: 08-31 22:53:30] {2282} INFO - iteration 40, current learner lgbm
# [flaml.automl.logger: 08-31 22:53:32] {2466} INFO -  at 95.1s,	estimator lgbm's best error=0.0024,	best estimator lgbm's best error=0.0024
# [flaml.automl.logger: 08-31 22:53:32] {2282} INFO - iteration 41, current learner lgbm
# [flaml.automl.logger: 08-31 22:53:35] {2466} INFO -  at 97.5s,	estimator lgbm's best error=0.0024,	best estimator lgbm's best error=0.0024
# [flaml.automl.logger: 08-31 22:53:35] {2282} INFO - iteration 42, current learner lgbm
# [flaml.automl.logger: 08-31 22:53:36] {2466} INFO -  at 99.3s,	estimator lgbm's best error=0.0024,	best estimator lgbm's best error=0.0024
# [flaml.automl.logger: 08-31 22:53:37] {2724} INFO - retrain lgbm for 0.3s
# [flaml.automl.logger: 08-31 22:53:37] {2727} INFO - retrained model: LGBMClassifier(colsample_bytree=0.9125000255612622,
#                learning_rate=0.3789319144277999, max_bin=255,
#                min_child_samples=96, n_estimators=24, n_jobs=-1, num_leaves=7,
#                reg_alpha=0.0009765625, reg_lambda=1.1381554699543146,
#                verbose=-1)
# [flaml.automl.logger: 08-31 22:53:37] {2009} INFO - fit succeeded
# [flaml.automl.logger: 08-31 22:53:37] {2010} INFO - Time taken to find the best model: 22.912930011749268
#   [AD+] AUC=0.691

# %%
import os
import pickle
import pandas as pd
from collections import Counter

# ---- Config ----
out_dir = "/Users/adithyamadduri/Desktop/Projects/proteomics_LGBM(ANML+Meta)"
classes = ["MCI", "NCI", "AD", "AD+"]
seeds = [1, 2, 3, 4, 5]

def safe_cls(c): return c.replace("+", "plus").replace(" ", "_").replace("/", "-")

# ---- Track all features with non-zero importance ----
feature_counts = Counter()

for seed in seeds:
    for cls in classes:
        model_path = os.path.join(out_dir, f"seed{seed}_{safe_cls(cls)}_automl.pkl")
        if not os.path.exists(model_path):
            print(f"Missing: {model_path}")
            continue

        with open(model_path, "rb") as f:
            automl = pickle.load(f)

        # Get feature importances
        importances = automl.model.estimator.feature_importances_
        features = automl.feature_names_in_

        # Filter to non-zero importance
        nonzero_features = [feat for feat, imp in zip(features, importances) if imp > 0]

        # Update count for each non-zero feature
        feature_counts.update(nonzero_features)

# ---- Filter to features appearing in at least 3 models ----
shared_features = [feat for feat, count in feature_counts.items() if count >= 3]
print(f"\n Found {len(shared_features)} features with non-zero importance in ≥3 models.\n")
print(shared_features)
# Out:
#  Found 338 features with non-zero importance in ≥3 models.
#
# ['10451-11', '11546-7', '14227-21', '21207-1', '3069-52', '3214-3', '7060-2', '7839-99', 'age_at_visit', 'APOE_34', '10000-28', '10085-25', '10367-62', '10462-14', '10565-19', '10569-28', '10672-75', '10705-14', '10714-7', '10816-150', '10980-11', '11089-7', '11135-5', '11142-11', '11192-168', '11243-90', '11293-14', '11351-233', '11436-6', '11450-110', '11457-53', '11516-7', '11814-29', '12077-32', '12384-92', '12430-78', '12650-43', '12712-9', '12727-7', '12904-180', '13098-93', '13118-5', '13406-161', '13453-2', '13496-19', '13567-1', '13610-9', '13692-154', '13710-6', '13732-79', '14005-2', '14091-42', '14105-5', '14115-34', '14689-3', '15391-114', '15468-14', '15491-20', '15503-15', '15503-20', '15559-5', '15635-4', '15653-9', '16292-288', '16320-139', '16614-27', '16916-19', '17170-15', '17672-184', '17685-9', '17710-40', '18175-65', '18337-4', '18411-83', '18831-6', '19112-2', '19206-20', '19238-12', '19264-6', '19296-51', '19369-17', '19392-6', '19638-9', '19760-26', '19803-34', '20055-40', '20067-26', '20187-10', '20444-12', '20453-9', '20558-4', '20965-18', '20966-7', '21113-3', '21117-18', '21314-11', '21649-12', '21691-27', '21698-11', '21713-11', '21728-4', '21764-99', '21768-9', '21916-82', '21999-61', '22070-5', '22377-27', '22414-127', '22544-10', '22576-2', '22782-80', '22801-83', '23259-23', '23271-20', '23323-25', '23340-37', '23571-93', '23690-228', '23767-1', '2381-52', '24215-8', '24286-48', '24431-32', '24693-5', '2474-54', '24926-9', '25060-18', '25121-7', '25259-7', '25913-17', '2638-12', '2762-30', '2797-56', '2925-9', '2937-10', '2943-5', '2994-71', '3029-52', '3045-72', '3049-61', '3066-12', '3173-49', '3181-50', '3326-58', '3362-61', '3364-76', '3390-72', '3415-61', '3461-58', '3676-15', '3719-2', '3727-35', '4153-11', '4278-14', '4481-34', '4500-50', '4534-10', '4697-59', '4891-50', '4906-35', '4914-10', '4917-62', '4982-54', '4991-12', '4992-49', '5087-5', '5090-49', '5231-79', '5350-14', '5410-53', '5661-15', '5675-6', '5691-2', '5698-60', '5701-81', '5727-35', '6042-52', '6077-63', '6232-54', '6252-62', '6390-18', '6420-4', '6423-66', '6431-68', '6469-62', '6472-40', '6530-63', '6576-1', '6597-24', '6627-25', '6909-40', '6986-17', '7131-8', '7148-42', '7182-1', '7648-9', '7695-106', '7920-30', '7948-129', '8042-88', '8231-122', '8299-66', '8325-37', '8382-47', '8396-42', '8429-16', '8700-325', '8780-2', '8838-10', '8840-61', '8841-65', '8908-14', '8960-3', '8997-4', '9015-1', '9264-11', '9335-28', '9449-150', '9573-108', '9627-15', '9719-145', '9928-125', '9936-27', '10612-18', '12578-13', '12800-5', '13101-60', '13113-7', '13747-9', '15364-101', '15387-44', '15486-126', '15511-37', '15631-18', '17166-4', '17202-37', '18376-19', '18887-7', '18914-188', '19196-73', '20529-7', '21124-17', '23546-9', '23644-19', '25126-19', '2670-67', '3235-50', '3311-27', '3605-77', '6453-70', '6458-6', '6462-12', '8233-2', '8364-74', '8973-23', '9838-4', '9964-10', '9987-30', '24494-67', '8288-27', '10442-1', '10464-6', '10902-53', '11320-29', '12818-159', '13583-19', '13704-5', '14099-20', '15613-16', '15640-54', '18931-40', '20591-48', '20970-14', '21112-6', '21161-16', '21182-8', '21343-3', '21384-2', '21475-137', '23252-4', '23284-5', '23296-29', '23303-131', '2620-4', '3166-92', '3232-28', '3352-80', '5095-21', '5954-62', '6334-9', '6350-43', '6392-7', '6440-31', '6448-36', '8007-19', '8246-9', '8631-13', '8924-55', '9216-100', '9748-31', '5363-51', '8427-118', '13429-3', '14022-17', '15584-9', '16305-10', '18882-7', '2278-61', '2781-63', '3309-2', '4135-84', '4930-21', '6568-18', '8469-41', '8951-162', '9574-11', '9898-161', '11204-80', '15361-37', '20436-93', '21499-17', '2765-4', '9578-263', '12734-112', '18389-11', '3499-77', '4763-31', '8464-31', '8813-160', '13650-11', '22500-9', '5457-5', '7854-38', '5015-15', '8074-32', '7769-29', '9974-8', '17756-69']

# %%
import os, glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# ---- Update this to match your proteomics run ----
folder = "/Users/adithyamadduri/Desktop/Projects/proteomics_LGBM(ANML+Meta)"
files = glob.glob(os.path.join(folder, "seed*_*.csv"))

# Infer class names from filenames (everything after 'seedX_')
def class_from_path(p):
    base = os.path.basename(p)
    return "_".join(base.split("_")[1:]).rsplit(".csv", 1)[0]

class_names = sorted(set(class_from_path(p) for p in files))

fpr_grid = np.linspace(0.0, 1.0, 200)

plt.figure(figsize=(10, 8))

for cls in class_names:
    cls_files = sorted(glob.glob(os.path.join(folder, f"seed*_{cls}.csv")))
    if not cls_files:
        continue

    tprs_interp, aucs = [], []

    for path in cls_files:
        df = pd.read_csv(path)
        y_true  = df["y_true"].astype(int).values
        y_score = df["y_score"].astype(float).values

        # EXACTLY like your ratios plot: use raw fpr/tpr directly
        fpr, tpr, _ = roc_curve(y_true, y_score)

        # Interpolate to common grid (no FPR de-dup)
        tpr_i = np.interp(fpr_grid, fpr, tpr)
        tpr_i[0] = 0.0  # match your ratios script
        tprs_interp.append(tpr_i)

        # AUC computed on raw fpr/tpr (no de-dup)
        aucs.append(auc(fpr, tpr))

    if not tprs_interp:
        continue

    mean_tpr = np.mean(tprs_interp, axis=0)
    std_tpr  = np.std(tprs_interp, axis=0)
    mean_auc = float(np.mean(aucs))
    std_auc  = float(np.std(aucs))

    plt.plot(
        fpr_grid, mean_tpr, lw=2,
        label=f"{cls.replace('_',' ')} (AUC = {mean_auc:.3f} ± {std_auc:.3f})"
    )
    plt.fill_between(
        fpr_grid,
        np.clip(mean_tpr - std_tpr, 0, 1),
        np.clip(mean_tpr + std_tpr, 0, 1),
        alpha=0.15
    )

# Chance line
plt.plot([0, 1], [0, 1], 'k--', label='Chance (AUC = 0.50)')

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('LGBM (Proteomics + Metadata)')
plt.legend(loc='lower right', fontsize=9)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
import os, glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_curve, average_precision_score

# ---- Update this to match your proteomics run ----
folder = "/Users/adithyamadduri/Desktop/Projects/proteomics_LGBM(ANML+Meta)"
files = glob.glob(os.path.join(folder, "seed*_*.csv"))

# Infer class names from filenames (everything after 'seedX_')
def class_from_path(p):
    base = os.path.basename(p)
    return "_".join(base.split("_")[1:]).rsplit(".csv", 1)[0]

class_names = sorted(set(class_from_path(p) for p in files))

recall_grid = np.linspace(0.0, 1.0, 200)
plt.figure(figsize=(10, 8))

ap_summary_rows = []

for cls in class_names:
    cls_files = sorted(glob.glob(os.path.join(folder, f"seed*_{cls}.csv")))
    if not cls_files:
        continue

    prec_interp_list, aps, prevalences = [], [], []

    for path in cls_files:
        df = pd.read_csv(path)
        y_true  = df["y_true"].astype(int).values
        y_score = df["y_score"].astype(float).values

        # skip degenerate splits
        pos = y_true.sum()
        if pos == 0 or pos == len(y_true):
            continue

        precision, recall, _ = precision_recall_curve(y_true, y_score)

        # deduplicate recall for interpolation
        uniq_idx = np.unique(recall, return_index=True)[1]
        r_u, p_u = recall[uniq_idx], precision[uniq_idx]

        # interpolate precision onto common recall grid
        p_i = np.interp(recall_grid, r_u, p_u, left=p_u[0], right=p_u[-1])
        prec_interp_list.append(p_i)

        aps.append(average_precision_score(y_true, y_score))
        prevalences.append(y_true.mean())

    if not prec_interp_list:
        print(f"[WARN] No valid PR curves for class {cls}")
        continue

    mean_prec = np.mean(prec_interp_list, axis=0)
    std_prec  = np.std(prec_interp_list, axis=0)
    mean_ap   = float(np.mean(aps))
    std_ap    = float(np.std(aps))
    n_splits  = len(aps)

    label_cls = cls.replace("_", " ")
    line, = plt.plot(recall_grid, mean_prec, lw=2,
                     label=f"{label_cls} (AP = {mean_ap:.3f} ± {std_ap:.3f})")
    plt.fill_between(recall_grid,
                     np.clip(mean_prec - std_prec, 0, 1),
                     np.clip(mean_prec + std_prec, 0, 1),
                     alpha=0.15, color=line.get_color())

    # per-class chance baseline = prevalence
    prev_mean = float(np.mean(prevalences))
    prev_sd   = float(np.std(prevalences))
    plt.hlines(prev_mean, 0, 1, colors=line.get_color(), linestyles="--", alpha=0.6)
    low, high = max(0, prev_mean - prev_sd), min(1, prev_mean + prev_sd)
    plt.fill_between([0, 1], [low, low], [high, high], color=line.get_color(), alpha=0.08)

    ap_summary_rows.append({
        "Class": label_cls, "Mean_AP": mean_ap, "Std_AP": std_ap,
        "Prev_Mean": prev_mean, "Prev_SD": prev_sd, "N": n_splits
    })

plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("LGBM (Proteomics + Demographics)\nPrecision–Recall (mean ± SD across seeds; dashed = prevalence)")
plt.legend(loc="upper right", fontsize=9)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# Optional: save figure + table
plot_path = os.path.join(folder, "pr_mean_across_seeds.png")
plt.savefig(plot_path, dpi=200)
if ap_summary_rows:
    ap_df = pd.DataFrame(ap_summary_rows).sort_values("Class")
    ap_csv = os.path.join(folder, "pr_ap_summary.csv")
    ap_df.to_csv(ap_csv, index=False)
    print(f"Saved plot to: {plot_path}")
    print(f"Saved AP summary to: {ap_csv}")
    print(ap_df.to_string(index=False))
# Out:
# Saved plot to: /Users/adithyamadduri/Desktop/Projects/proteomics_LGBM(ANML+Meta)/pr_mean_across_seeds.png
# Saved AP summary to: /Users/adithyamadduri/Desktop/Projects/proteomics_LGBM(ANML+Meta)/pr_ap_summary.csv
#  Class  Mean_AP   Std_AP  Prev_Mean  Prev_SD  N
#     AD 0.410182 0.031111   0.176479 0.002401  5
# ADplus 0.053145 0.034425   0.017004 0.001345  5
#    MCI 0.301119 0.023089   0.278570 0.004115  5
#    NCI 0.667049 0.044348   0.527947 0.005547  5

# %%
import os
import pickle
import pandas as pd
import matplotlib.pyplot as plt
from collections import defaultdict

# ---- Paths ----
model_dir = "/Users/adithyamadduri/Desktop/Projects/proteomics_LGBM(ANML+Meta)"
protein_metadata_path = "/Users/adithyamadduri/Downloads/syn65414912/OhNM2025_ROSMAP_plasma_Soma7k_protein_metadata.csv"

# ---- Load mapping: SeqId → EntrezGeneSymbol ----
df_meta = pd.read_csv(protein_metadata_path)
seqid_to_gene = dict(zip(df_meta["SeqId"], df_meta["EntrezGeneSymbol"]))

# ---- Init storage: class → list of importance dataframes ----
class_to_importances = defaultdict(list)

# ---- Helper: get class name from file ----
def extract_class_from_filename(f):
    base = os.path.basename(f)
    cls = base.split("_", 1)[-1].replace("_automl.pkl", "")
    return cls

# ---- Load and normalize importances ----
model_files = [f for f in os.listdir(model_dir) if f.endswith("_automl.pkl")]

for model_file in model_files:
    cls = extract_class_from_filename(model_file)
    path = os.path.join(model_dir, model_file)

    with open(path, "rb") as f:
        automl = pickle.load(f)

    model = automl.model.estimator
    feature_names = model.feature_name_
    raw_importance = model.feature_importances_

    # Normalize
    norm_importance = raw_importance / raw_importance.sum()

    # Map to gene names
    gene_names = [seqid_to_gene.get(f, f) for f in feature_names]

    df = pd.DataFrame({
        "Gene": gene_names,
        "Importance": norm_importance
    })
    class_to_importances[cls].append(df)

# ---- Plot mean importance for each class ----
TOP_N = 10

for cls, dfs in class_to_importances.items():
    all_df = pd.concat(dfs)
    mean_df = all_df.groupby("Gene")["Importance"].mean()
    top_genes = mean_df.sort_values(ascending=False).head(TOP_N)

    # Plot
    plt.figure(figsize=(10, 6))
    plt.barh(top_genes.index[::-1], top_genes.values[::-1], color="darkgreen")
    plt.xlabel("Mean Normalized Feature Importance")
    plt.title(f"Top {TOP_N} Genes — Class {cls.replace('plus','+')}")
    plt.tight_layout()

    # Save plot
    out_path = os.path.join(model_dir, f"{cls}_mean_importance_top{TOP_N}.png")
    plt.savefig(out_path)
    plt.show()

    print(f"Saved: {out_path}")
# Out:
# Saved: /Users/adithyamadduri/Desktop/Projects/proteomics_LGBM(ANML+Meta)/NCI_mean_importance_top10.png
# Saved: /Users/adithyamadduri/Desktop/Projects/proteomics_LGBM(ANML+Meta)/AD_mean_importance_top10.png
# Saved: /Users/adithyamadduri/Desktop/Projects/proteomics_LGBM(ANML+Meta)/ADplus_mean_importance_top10.png
# Saved: /Users/adithyamadduri/Desktop/Projects/proteomics_LGBM(ANML+Meta)/MCI_mean_importance_top10.png

# %%
import os
import pickle
import pandas as pd
import matplotlib.pyplot as plt
import shap
from collections import defaultdict

# ---- Paths ----
model_dir = "/Users/adithyamadduri/Desktop/Projects/proteomics_LGBM(ANML+Meta)"
protein_metadata_path = "/Users/adithyamadduri/Downloads/syn65414912/OhNM2025_ROSMAP_plasma_Soma7k_protein_metadata.csv"

# ---- Load mapping: SeqId → EntrezGeneSymbol ----
df_meta = pd.read_csv(protein_metadata_path)
seqid_to_gene = dict(zip(df_meta["SeqId"], df_meta["EntrezGeneSymbol"]))

# ---- Helper ----
def extract_class_from_filename(f):
    base = os.path.basename(f)
    cls = base.split("_", 1)[-1].replace("_automl.pkl", "")
    return cls

# ---- Load SHAP importances ----
class_to_shap_importances = defaultdict(list)
TOP_N = 10

model_files = [f for f in os.listdir(model_dir) if f.endswith("_automl.pkl")]

for model_file in model_files:
    cls = extract_class_from_filename(model_file)
    model_path = os.path.join(model_dir, model_file)

    with open(model_path, "rb") as f:
        automl = pickle.load(f)

    model = automl.model.estimator
    feature_names = model.feature_name_
    
    # Try to get training data
    try:
        X_train = automl.X_train  # works if stored
    except AttributeError:
        print(f"Skipping {cls}: training data not stored in AutoML object.")
        continue

    explainer = shap.TreeExplainer(model)
    shap_values = explainer.shap_values(X_train)

    # Handle multiclass
    if isinstance(shap_values, list):
        shap_values = shap_values[1]  # assume binary, take class 1

    mean_shap = np.abs(shap_values).mean(axis=0)
    gene_names = [seqid_to_gene.get(f, f) for f in feature_names]

    df = pd.DataFrame({
        "Gene": gene_names,
        "SHAP": mean_shap
    })
    class_to_shap_importances[cls].append(df)

# ---- Plot mean SHAP per class ----
for cls, dfs in class_to_shap_importances.items():
    all_df = pd.concat(dfs)
    mean_df = all_df.groupby("Gene")["SHAP"].mean()
    top_genes = mean_df.sort_values(ascending=False).head(TOP_N)

    plt.figure(figsize=(10, 6))
    plt.barh(top_genes.index[::-1], top_genes.values[::-1], color="purple")
    plt.xlabel("Mean Absolute SHAP Value")
    plt.title(f"Top {TOP_N} Genes by SHAP — Class {cls.replace('plus','+')}")
    plt.tight_layout()

    out_path = os.path.join(model_dir, f"{cls}_mean_SHAP_top{TOP_N}.png")
    plt.savefig(out_path)
    plt.show()

    print(f"Saved SHAP plot: {out_path}")
# Out:
# Skipping NCI: training data not stored in AutoML object.
# Skipping AD: training data not stored in AutoML object.
# Skipping NCI: training data not stored in AutoML object.
# Skipping NCI: training data not stored in AutoML object.
# Skipping NCI: training data not stored in AutoML object.
# Skipping AD: training data not stored in AutoML object.
# Skipping AD: training data not stored in AutoML object.
# Skipping NCI: training data not stored in AutoML object.
# Skipping ADplus: training data not stored in AutoML object.
# Skipping ADplus: training data not stored in AutoML object.
# Skipping MCI: training data not stored in AutoML object.
# Skipping MCI: training data not stored in AutoML object.
# Skipping ADplus: training data not stored in AutoML object.
# Skipping MCI: training data not stored in AutoML object.
# Skipping AD: training data not stored in AutoML object.
# Skipping ADplus: training data not stored in AutoML object.
# Skipping AD: training data not stored in AutoML object.
# Skipping MCI: training data not stored in AutoML object.
# Skipping ADplus: training data not stored in AutoML object.
# Skipping MCI: training data not stored in AutoML object.
# /var/folders/yr/4bplyc1x1tq4xz4jckbg_8wr0000gn/T/ipykernel_6167/2994422711.py:33: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   automl = pickle.load(f)
# /var/folders/yr/4bplyc1x1tq4xz4jckbg_8wr0000gn/T/ipykernel_6167/2994422711.py:33: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   automl = pickle.load(f)
# /var/folders/yr/4bplyc1x1tq4xz4jckbg_8wr0000gn/T/ipykernel_6167/2994422711.py:33: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   automl = pickle.load(f)
# /var/folders/yr/4bplyc1x1tq4xz4jckbg_8wr0000gn/T/ipykernel_6167/2994422711.py:33: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   automl = pickle.load(f)
# /var/folders/yr/4bplyc1x1tq4xz4jckbg_8wr0000gn/T/ipykernel_6167/2994422711.py:33: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   automl = pickle.load(f)
# /var/folders/yr/4bplyc1x1tq4xz4jckbg_8wr0000gn/T/ipykernel_6167/2994422711.py:33: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   automl = pickle.load(f)
# /var/folders/yr/4bplyc1x1tq4xz4jckbg_8wr0000gn/T/ipykernel_6167/2994422711.py:33: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   automl = pickle.load(f)
# /var/folders/yr/4bplyc1x1tq4xz4jckbg_8wr0000gn/T/ipykernel_6167/2994422711.py:33: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   automl = pickle.load(f)
# /var/folders/yr/4bplyc1x1tq4xz4jckbg_8wr0000gn/T/ipykernel_6167/2994422711.py:33: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   automl = pickle.load(f)
# /var/folders/yr/4bplyc1x1tq4xz4jckbg_8wr0000gn/T/ipykernel_6167/2994422711.py:33: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   automl = pickle.load(f)
# /var/folders/yr/4bplyc1x1tq4xz4jckbg_8wr0000gn/T/ipykernel_6167/2994422711.py:33: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   automl = pickle.load(f)
# /var/folders/yr/4bplyc1x1tq4xz4jckbg_8wr0000gn/T/ipykernel_6167/2994422711.py:33: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   automl = pickle.load(f)
# /var/folders/yr/4bplyc1x1tq4xz4jckbg_8wr0000gn/T/ipykernel_6167/2994422711.py:33: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   automl = pickle.load(f)
# /var/folders/yr/4bplyc1x1tq4xz4jckbg_8wr0000gn/T/ipykernel_6167/2994422711.py:33: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   automl = pickle.load(f)
# /var/folders/yr/4bplyc1x1tq4xz4jckbg_8wr0000gn/T/ipykernel_6167/2994422711.py:33: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   automl = pickle.load(f)
# /var/folders/yr/4bplyc1x1tq4xz4jckbg_8wr0000gn/T/ipykernel_6167/2994422711.py:33: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   automl = pickle.load(f)
# /var/folders/yr/4bplyc1x1tq4xz4jckbg_8wr0000gn/T/ipykernel_6167/2994422711.py:33: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   automl = pickle.load(f)
# /var/folders/yr/4bplyc1x1tq4xz4jckbg_8wr0000gn/T/ipykernel_6167/2994422711.py:33: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   automl = pickle.load(f)
# /var/folders/yr/4bplyc1x1tq4xz4jckbg_8wr0000gn/T/ipykernel_6167/2994422711.py:33: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   automl = pickle.load(f)
# /var/folders/yr/4bplyc1x1tq4xz4jckbg_8wr0000gn/T/ipykernel_6167/2994422711.py:33: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   automl = pickle.load(f)
