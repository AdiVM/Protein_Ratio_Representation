# %%
# =========================
# BLOCK 1 — PREPROCESSING
# =========================
import os
import numpy as np
import pandas as pd
from sklearn.preprocessing import OneHotEncoder

# ---- File paths ----
BASE = "/Users/adithyamadduri/Downloads/syn65414912"
ANML_PATH   = os.path.join(BASE, "OhNM2025_ROSMAP_plasma_Soma7k_protein_level_ANML_log10.csv")
SAMPLE_PATH = os.path.join(BASE, "OhNM2025_ROSMAP_plasma_Soma7k_sample_metadata.csv")

# ---- Load ----
df_levels = pd.read_csv(ANML_PATH)        # rows: projid_visit, cols: proteins
df_meta   = pd.read_csv(SAMPLE_PATH)      # contains projid_visit, projid, msex, age_at_visit, educ, apoe_genotype, Diagnosis

# ---- Sanity: keys present? ----
assert "projid_visit" in df_levels.columns, "projid_visit missing in protein matrix."
for col in ["projid_visit","projid","msex","age_at_visit","educ","apoe_genotype","Diagnosis"]:
    assert col in df_meta.columns, f"{col} missing in sample metadata."

# ---- Align on visit ----
# inner join so we only keep visits present in BOTH
df = pd.merge(df_meta, df_levels, on="projid_visit", how="inner", validate="one_to_one")
print("Aligned shape:", df.shape)

# ---- Labels (four groups) ----
df["Diagnosis"] = df["Diagnosis"].astype(str).str.strip()
valid_classes = {"MCI","NCI","AD","AD+"}
df = df[df["Diagnosis"].isin(valid_classes)].reset_index(drop=True)
print("Class counts:\n", df["Diagnosis"].value_counts())

# ---- Grouping key for leakage control ----
df["projid"] = df["projid"].astype(str)

# ---- Stratification label: Diagnosis × sex (0/1) ----
df["msex"] = df["msex"].astype(int)
df["strata"] = df["Diagnosis"] + "_" + df["msex"].astype(str)

# ---- APOE one-hot (Unknown for NaN) ----
def format_apoe(x):
    if pd.isna(x):
        return "Unknown"
    try:
        # e.g., 33.0 -> "33"
        return str(int(float(x)))
    except Exception:
        s = str(x).strip()
        return s if s else "Unknown"

df["apoe_str"] = df["apoe_genotype"].apply(format_apoe)

# scikit-learn compatibility across versions
try:
    ohe = OneHotEncoder(sparse_output=False, handle_unknown="ignore")
except TypeError:
    ohe = OneHotEncoder(sparse=False, handle_unknown="ignore")

apoe_ohe = ohe.fit_transform(df[["apoe_str"]])
apoe_cols = [c.replace("apoe_str_","APOE_") for c in ohe.get_feature_names_out()]
df_apoe  = pd.DataFrame(apoe_ohe, columns=apoe_cols, index=df.index)

# ---- Numeric covariates (unscaled) ----
for col in ["age_at_visit","educ"]:
    df[col] = pd.to_numeric(df[col], errors="coerce")

# ---- Protein feature columns ----
protein_cols = [c for c in df_levels.columns if c != "projid_visit"]

# ---- Final feature matrix X ----
# X = pd.concat([df[["age_at_visit","educ"]], df_apoe, df[protein_cols]], axis=1)
X = df[protein_cols].copy()
y = df["Diagnosis"].astype(str).values
groups = df["projid"].values
strata = df["strata"].values

print("X shape:", X.shape)
print("APOE levels seen:", sorted(set(df["apoe_str"])))
# Out:
# Aligned shape: (973, 7301)
# Class counts:
#  Diagnosis
# NCI    507
# MCI    262
# AD     167
# AD+     17
# Name: count, dtype: int64
# X shape: (953, 7289)
# APOE levels seen: ['22', '23', '24', '33', '34', '44', 'Unknown']

# %%
# =========================
# BLOCK 2 — TRAINING
# =========================
import os
import numpy as np
import pandas as pd
from flaml import AutoML
from sklearn.metrics import roc_auc_score

# ---- Output folder ----
# This is the original folder that this code used to write to. It seems at some point I renamed this folder to _fixed. Now confirming that these results match fixed.
# out_dir = "/Users/adithyamadduri/Desktop/Projects/proteomics_LGBM(ANML+Meta)"

out_dir = "/Users/adithyamadduri/Desktop/Projects/ratios_project/Revision/Results/Proteins_only"
os.makedirs(out_dir, exist_ok=True)

# ---- Helper: group-aware stratified 70/30 split (by mode of strata per subject) ----
def group_stratified_shuffle_split(df_index, strata_all, groups_all, test_size=0.30, random_state=0):
    """Return train_idx, test_idx ensuring groups stay intact and class-sex balance is approx preserved.
       Strategy: assign each group a single stratum = mode(strata) among its rows, then stratified split at group level.
    """
    rng = np.random.RandomState(random_state)
    data = pd.DataFrame({"idx": df_index, "strata": strata_all, "group": groups_all})

    # group -> mode(strata)
    grp_mode = (
        data.groupby("group")["strata"]
        .agg(lambda s: s.value_counts().idxmax())
    )
    grp_mode = grp_mode.sample(frac=1.0, random_state=random_state)  # shuffle groups

    train_groups, test_groups = [], []
    for s_val, grp_ids in grp_mode.groupby(grp_mode.values):
        g_list = list(grp_ids.index)
        rng.shuffle(g_list)
        n_test = max(1, int(round(test_size * len(g_list))))
        test_groups.extend(g_list[:n_test])
        train_groups.extend(g_list[n_test:])

    train_mask = np.isin(groups_all, train_groups)
    test_mask  = np.isin(groups_all,  test_groups)
    return np.where(train_mask)[0], np.where(test_mask)[0]

# ---- Classes & seeds ----
classes = ["MCI","NCI","AD","AD+"]     # will save AD+ as 'ADplus' in filenames
def safe_cls(c): return c.replace("+","plus").replace(" ","_").replace("/","-")

seeds = [1,2,3,4,5]

# ---- Main loop ----
for seed in seeds:
    tr_idx, te_idx = group_stratified_shuffle_split(
        df_index=np.arange(len(X)),
        strata_all=strata,
        groups_all=groups,
        test_size=0.30,
        random_state=seed,
    )

    X_train, X_test = X.iloc[tr_idx], X.iloc[te_idx]
    y_train_full    = y[tr_idx]
    y_test_full     = y[te_idx]

    print(f"\n[Seed {seed}] Train n={len(tr_idx)} | Test n={len(te_idx)} | "
          f"Groups train={len(np.unique(groups[tr_idx]))} test={len(np.unique(groups[te_idx]))}")

    for cls in classes:
        y_train = (y_train_full == cls).astype(int)
        y_test  = (y_test_full  == cls).astype(int)

        automl = AutoML()
        settings = {
            "time_budget": 100,               # seconds per class; adjust if you want longer searches
            "metric": "roc_auc",
            "task": "classification",
            "eval_method": "cv",
            "estimator_list": ["lgbm"],       # force LightGBM
            "log_file_name": os.path.join(out_dir, f"flaml_seed{seed}_{safe_cls(cls)}.log"),
            "seed": seed,
        }
        automl.fit(X_train=X_train, y_train=y_train, **settings)
        automl.pickle(os.path.join(out_dir, f"seed{seed}_{safe_cls(cls)}_automl.pkl"))

        # Predict proba for positive class
        y_score = automl.predict_proba(X_test)[:, 1]
        auc = roc_auc_score(y_test, y_score) if (y_test.sum() > 0 and y_test.sum() < len(y_test)) else float("nan")
        print(f"  [{cls}] AUC={auc:.3f}")

        # Save per-class CSV for your existing averaging/plotting script
        out_csv = os.path.join(out_dir, f"seed{seed}_{safe_cls(cls)}.csv")
        pd.DataFrame({"y_true": y_test.astype(int), "y_score": y_score.astype(float)}).to_csv(out_csv, index=False)
# Out:
# [Seed 1] Train n=670 | Test n=283 | Groups train=610 test=261
# [flaml.automl.logger: 02-02 22:04:07] {1752} INFO - task = classification
# [flaml.automl.logger: 02-02 22:04:07] {1763} INFO - Evaluation method: cv
# [flaml.automl.logger: 02-02 22:04:07] {1862} INFO - Minimizing error metric: 1-roc_auc
# [flaml.automl.logger: 02-02 22:04:07] {1979} INFO - List of ML learners in AutoML Run: ['lgbm']
# [flaml.automl.logger: 02-02 22:04:07] {2282} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 02-02 22:04:09] {2417} INFO - Estimated sufficient time budget=18454s. Estimated necessary time budget=18s.
# [flaml.automl.logger: 02-02 22:04:09] {2466} INFO -  at 3.4s,	estimator lgbm's best error=0.3928,	best estimator lgbm's best error=0.3928
# [flaml.automl.logger: 02-02 22:04:09] {2282} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 02-02 22:04:10] {2466} INFO -  at 5.1s,	estimator lgbm's best error=0.3928,	best estimator lgbm's best error=0.3928
# [flaml.automl.logger: 02-02 22:04:10] {2282} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 02-02 22:04:12] {2466} INFO -  at 6.8s,	estimator lgbm's best error=0.3928,	best estimator lgbm's best error=0.3928
# [flaml.automl.logger: 02-02 22:04:12] {2282} INFO - iteration 3, current learner lgbm
# [flaml.automl.logger: 02-02 22:04:14] {2466} INFO -  at 8.6s,	estimator lgbm's best error=0.3928,	best estimator lgbm's best error=0.3928
# [flaml.automl.logger: 02-02 22:04:14] {2282} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 02-02 22:04:16] {2466} INFO -  at 10.5s,	estimator lgbm's best error=0.3928,	best estimator lgbm's best error=0.3928
# [flaml.automl.logger: 02-02 22:04:16] {2282} INFO - iteration 5, current learner lgbm
# [flaml.automl.logger: 02-02 22:04:17] {2466} INFO -  at 12.3s,	estimator lgbm's best error=0.3928,	best estimator lgbm's best error=0.3928
# [flaml.automl.logger: 02-02 22:04:17] {2282} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 02-02 22:04:19] {2466} INFO -  at 14.0s,	estimator lgbm's best error=0.3928,	best estimator lgbm's best error=0.3928
# [flaml.automl.logger: 02-02 22:04:19] {2282} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 02-02 22:04:21] {2466} INFO -  at 15.7s,	estimator lgbm's best error=0.3928,	best estimator lgbm's best error=0.3928
# [flaml.automl.logger: 02-02 22:04:21] {2282} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 02-02 22:04:23] {2466} INFO -  at 17.4s,	estimator lgbm's best error=0.3928,	best estimator lgbm's best error=0.3928
# [flaml.automl.logger: 02-02 22:04:23] {2282} INFO - iteration 9, current learner lgbm
# [flaml.automl.logger: 02-02 22:04:24] {2466} INFO -  at 19.1s,	estimator lgbm's best error=0.3928,	best estimator lgbm's best error=0.3928
# [flaml.automl.logger: 02-02 22:04:24] {2282} INFO - iteration 10, current learner lgbm
# [flaml.automl.logger: 02-02 22:04:26] {2466} INFO -  at 21.0s,	estimator lgbm's best error=0.3928,	best estimator lgbm's best error=0.3928
# [flaml.automl.logger: 02-02 22:04:26] {2282} INFO - iteration 11, current learner lgbm
# [flaml.automl.logger: 02-02 22:04:28] {2466} INFO -  at 22.9s,	estimator lgbm's best error=0.3928,	best estimator lgbm's best error=0.3928
# [flaml.automl.logger: 02-02 22:04:28] {2282} INFO - iteration 12, current learner lgbm
# [flaml.automl.logger: 02-02 22:04:30] {2466} INFO -  at 24.6s,	estimator lgbm's best error=0.3928,	best estimator lgbm's best error=0.3928
# [flaml.automl.logger: 02-02 22:04:30] {2282} INFO - iteration 13, current learner lgbm
# [flaml.automl.logger: 02-02 22:04:31] {2466} INFO -  at 26.2s,	estimator lgbm's best error=0.3928,	best estimator lgbm's best error=0.3928
# [flaml.automl.logger: 02-02 22:04:31] {2282} INFO - iteration 14, current learner lgbm
# [flaml.automl.logger: 02-02 22:04:33] {2466} INFO -  at 28.1s,	estimator lgbm's best error=0.3928,	best estimator lgbm's best error=0.3928
# [flaml.automl.logger: 02-02 22:04:33] {2282} INFO - iteration 15, current learner lgbm
# [flaml.automl.logger: 02-02 22:04:35] {2466} INFO -  at 29.8s,	estimator lgbm's best error=0.3928,	best estimator lgbm's best error=0.3928
# [flaml.automl.logger: 02-02 22:04:35] {2282} INFO - iteration 16, current learner lgbm
# [flaml.automl.logger: 02-02 22:04:37] {2466} INFO -  at 31.7s,	estimator lgbm's best error=0.3928,	best estimator lgbm's best error=0.3928
# [flaml.automl.logger: 02-02 22:04:37] {2282} INFO - iteration 17, current learner lgbm
# [flaml.automl.logger: 02-02 22:04:39] {2466} INFO -  at 33.4s,	estimator lgbm's best error=0.3928,	best estimator lgbm's best error=0.3928
# [flaml.automl.logger: 02-02 22:04:39] {2282} INFO - iteration 18, current learner lgbm
# [flaml.automl.logger: 02-02 22:04:40] {2466} INFO -  at 35.3s,	estimator lgbm's best error=0.3928,	best estimator lgbm's best error=0.3928
# [flaml.automl.logger: 02-02 22:04:40] {2282} INFO - iteration 19, current learner lgbm
# [flaml.automl.logger: 02-02 22:04:42] {2466} INFO -  at 36.9s,	estimator lgbm's best error=0.3928,	best estimator lgbm's best error=0.3928
# [flaml.automl.logger: 02-02 22:04:42] {2282} INFO - iteration 20, current learner lgbm
# [flaml.automl.logger: 02-02 22:04:44] {2466} INFO -  at 38.7s,	estimator lgbm's best error=0.3928,	best estimator lgbm's best error=0.3928
# [flaml.automl.logger: 02-02 22:04:44] {2282} INFO - iteration 21, current learner lgbm
# [flaml.automl.logger: 02-02 22:04:46] {2466} INFO -  at 40.4s,	estimator lgbm's best error=0.3928,	best estimator lgbm's best error=0.3928
# [flaml.automl.logger: 02-02 22:04:46] {2282} INFO - iteration 22, current learner lgbm
# [flaml.automl.logger: 02-02 22:04:47] {2466} INFO -  at 42.2s,	estimator lgbm's best error=0.3928,	best estimator lgbm's best error=0.3928
# [flaml.automl.logger: 02-02 22:04:47] {2282} INFO - iteration 23, current learner lgbm
# [flaml.automl.logger: 02-02 22:04:49] {2466} INFO -  at 44.0s,	estimator lgbm's best error=0.3903,	best estimator lgbm's best error=0.3903
# [flaml.automl.logger: 02-02 22:04:49] {2282} INFO - iteration 24, current learner lgbm
# [flaml.automl.logger: 02-02 22:04:51] {2466} INFO -  at 45.8s,	estimator lgbm's best error=0.3903,	best estimator lgbm's best error=0.3903
# [flaml.automl.logger: 02-02 22:04:51] {2282} INFO - iteration 25, current learner lgbm
# [flaml.automl.logger: 02-02 22:04:53] {2466} INFO -  at 47.5s,	estimator lgbm's best error=0.3903,	best estimator lgbm's best error=0.3903
# [flaml.automl.logger: 02-02 22:04:53] {2282} INFO - iteration 26, current learner lgbm
# [flaml.automl.logger: 02-02 22:04:54] {2466} INFO -  at 49.3s,	estimator lgbm's best error=0.3903,	best estimator lgbm's best error=0.3903
# [flaml.automl.logger: 02-02 22:04:54] {2282} INFO - iteration 27, current learner lgbm
# [flaml.automl.logger: 02-02 22:04:56] {2466} INFO -  at 51.0s,	estimator lgbm's best error=0.3903,	best estimator lgbm's best error=0.3903
# [flaml.automl.logger: 02-02 22:04:56] {2282} INFO - iteration 28, current learner lgbm
# [flaml.automl.logger: 02-02 22:04:58] {2466} INFO -  at 52.7s,	estimator lgbm's best error=0.3903,	best estimator lgbm's best error=0.3903
# [flaml.automl.logger: 02-02 22:04:58] {2282} INFO - iteration 29, current learner lgbm
# [flaml.automl.logger: 02-02 22:05:00] {2466} INFO -  at 54.4s,	estimator lgbm's best error=0.3903,	best estimator lgbm's best error=0.3903
# [flaml.automl.logger: 02-02 22:05:00] {2282} INFO - iteration 30, current learner lgbm
# [flaml.automl.logger: 02-02 22:05:01] {2466} INFO -  at 56.1s,	estimator lgbm's best error=0.3903,	best estimator lgbm's best error=0.3903
# [flaml.automl.logger: 02-02 22:05:01] {2282} INFO - iteration 31, current learner lgbm
# [flaml.automl.logger: 02-02 22:05:03] {2466} INFO -  at 57.9s,	estimator lgbm's best error=0.3903,	best estimator lgbm's best error=0.3903
# [flaml.automl.logger: 02-02 22:05:03] {2282} INFO - iteration 32, current learner lgbm
# [flaml.automl.logger: 02-02 22:05:05] {2466} INFO -  at 59.6s,	estimator lgbm's best error=0.3903,	best estimator lgbm's best error=0.3903
# [flaml.automl.logger: 02-02 22:05:05] {2282} INFO - iteration 33, current learner lgbm
# [flaml.automl.logger: 02-02 22:05:06] {2466} INFO -  at 61.3s,	estimator lgbm's best error=0.3903,	best estimator lgbm's best error=0.3903
# [flaml.automl.logger: 02-02 22:05:06] {2282} INFO - iteration 34, current learner lgbm
# [flaml.automl.logger: 02-02 22:05:08] {2466} INFO -  at 63.1s,	estimator lgbm's best error=0.3903,	best estimator lgbm's best error=0.3903
# [flaml.automl.logger: 02-02 22:05:08] {2282} INFO - iteration 35, current learner lgbm
# [flaml.automl.logger: 02-02 22:05:10] {2466} INFO -  at 64.8s,	estimator lgbm's best error=0.3903,	best estimator lgbm's best error=0.3903
# [flaml.automl.logger: 02-02 22:05:10] {2282} INFO - iteration 36, current learner lgbm
# [flaml.automl.logger: 02-02 22:05:12] {2466} INFO -  at 66.5s,	estimator lgbm's best error=0.3903,	best estimator lgbm's best error=0.3903
# [flaml.automl.logger: 02-02 22:05:12] {2282} INFO - iteration 37, current learner lgbm
# [flaml.automl.logger: 02-02 22:05:14] {2466} INFO -  at 68.6s,	estimator lgbm's best error=0.3903,	best estimator lgbm's best error=0.3903
# [flaml.automl.logger: 02-02 22:05:14] {2282} INFO - iteration 38, current learner lgbm
# [flaml.automl.logger: 02-02 22:05:15] {2466} INFO -  at 70.3s,	estimator lgbm's best error=0.3903,	best estimator lgbm's best error=0.3903
# [flaml.automl.logger: 02-02 22:05:15] {2282} INFO - iteration 39, current learner lgbm
# [flaml.automl.logger: 02-02 22:05:17] {2466} INFO -  at 72.1s,	estimator lgbm's best error=0.3903,	best estimator lgbm's best error=0.3903
# [flaml.automl.logger: 02-02 22:05:17] {2282} INFO - iteration 40, current learner lgbm
# [flaml.automl.logger: 02-02 22:05:19] {2466} INFO -  at 73.8s,	estimator lgbm's best error=0.3903,	best estimator lgbm's best error=0.3903
# [flaml.automl.logger: 02-02 22:05:19] {2282} INFO - iteration 41, current learner lgbm
# [flaml.automl.logger: 02-02 22:05:21] {2466} INFO -  at 75.6s,	estimator lgbm's best error=0.3903,	best estimator lgbm's best error=0.3903
# [flaml.automl.logger: 02-02 22:05:21] {2282} INFO - iteration 42, current learner lgbm
# [flaml.automl.logger: 02-02 22:05:23] {2466} INFO -  at 77.4s,	estimator lgbm's best error=0.3903,	best estimator lgbm's best error=0.3903
# [flaml.automl.logger: 02-02 22:05:23] {2282} INFO - iteration 43, current learner lgbm
# [flaml.automl.logger: 02-02 22:05:25] {2466} INFO -  at 79.4s,	estimator lgbm's best error=0.3903,	best estimator lgbm's best error=0.3903
# [flaml.automl.logger: 02-02 22:05:25] {2282} INFO - iteration 44, current learner lgbm
# [flaml.automl.logger: 02-02 22:05:26] {2466} INFO -  at 81.2s,	estimator lgbm's best error=0.3903,	best estimator lgbm's best error=0.3903
# [flaml.automl.logger: 02-02 22:05:26] {2282} INFO - iteration 45, current learner lgbm
# [flaml.automl.logger: 02-02 22:05:28] {2466} INFO -  at 82.9s,	estimator lgbm's best error=0.3903,	best estimator lgbm's best error=0.3903
# [flaml.automl.logger: 02-02 22:05:28] {2282} INFO - iteration 46, current learner lgbm
# [flaml.automl.logger: 02-02 22:05:30] {2466} INFO -  at 84.4s,	estimator lgbm's best error=0.3903,	best estimator lgbm's best error=0.3903
# [flaml.automl.logger: 02-02 22:05:30] {2282} INFO - iteration 47, current learner lgbm
# [flaml.automl.logger: 02-02 22:05:31] {2466} INFO -  at 86.3s,	estimator lgbm's best error=0.3903,	best estimator lgbm's best error=0.3903
# [flaml.automl.logger: 02-02 22:05:31] {2282} INFO - iteration 48, current learner lgbm
# [flaml.automl.logger: 02-02 22:05:33] {2466} INFO -  at 88.0s,	estimator lgbm's best error=0.3903,	best estimator lgbm's best error=0.3903
# [flaml.automl.logger: 02-02 22:05:33] {2282} INFO - iteration 49, current learner lgbm
# [flaml.automl.logger: 02-02 22:05:35] {2466} INFO -  at 89.7s,	estimator lgbm's best error=0.3903,	best estimator lgbm's best error=0.3903
# [flaml.automl.logger: 02-02 22:05:35] {2282} INFO - iteration 50, current learner lgbm
# [flaml.automl.logger: 02-02 22:05:37] {2466} INFO -  at 91.5s,	estimator lgbm's best error=0.3903,	best estimator lgbm's best error=0.3903
# [flaml.automl.logger: 02-02 22:05:37] {2282} INFO - iteration 51, current learner lgbm
# [flaml.automl.logger: 02-02 22:05:38] {2466} INFO -  at 93.2s,	estimator lgbm's best error=0.3903,	best estimator lgbm's best error=0.3903
# [flaml.automl.logger: 02-02 22:05:38] {2282} INFO - iteration 52, current learner lgbm
# [flaml.automl.logger: 02-02 22:05:40] {2466} INFO -  at 94.9s,	estimator lgbm's best error=0.3903,	best estimator lgbm's best error=0.3903
# [flaml.automl.logger: 02-02 22:05:40] {2282} INFO - iteration 53, current learner lgbm
# [flaml.automl.logger: 02-02 22:05:42] {2466} INFO -  at 96.6s,	estimator lgbm's best error=0.3903,	best estimator lgbm's best error=0.3903
# [flaml.automl.logger: 02-02 22:05:42] {2282} INFO - iteration 54, current learner lgbm
# [flaml.automl.logger: 02-02 22:05:43] {2466} INFO -  at 98.3s,	estimator lgbm's best error=0.3903,	best estimator lgbm's best error=0.3903
# [flaml.automl.logger: 02-02 22:05:44] {2724} INFO - retrain lgbm for 0.2s
# [flaml.automl.logger: 02-02 22:05:44] {2727} INFO - retrained model: LGBMClassifier(learning_rate=np.float64(0.15247143318707326), max_bin=255,
#                min_child_samples=24, n_estimators=4, n_jobs=-1, num_leaves=5,
#                reg_alpha=0.0009765625, reg_lambda=np.float64(4.714190545868553),
#                verbose=-1)
# [flaml.automl.logger: 02-02 22:05:44] {2009} INFO - fit succeeded
# [flaml.automl.logger: 02-02 22:05:44] {2010} INFO - Time taken to find the best model: 44.02564096450806
#   [MCI] AUC=0.468
# [flaml.automl.logger: 02-02 22:05:46] {1752} INFO - task = classification
# [flaml.automl.logger: 02-02 22:05:46] {1763} INFO - Evaluation method: cv
# [flaml.automl.logger: 02-02 22:05:46] {1862} INFO - Minimizing error metric: 1-roc_auc
# [flaml.automl.logger: 02-02 22:05:46] {1979} INFO - List of ML learners in AutoML Run: ['lgbm']
# [flaml.automl.logger: 02-02 22:05:46] {2282} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 02-02 22:05:48] {2417} INFO - Estimated sufficient time budget=18902s. Estimated necessary time budget=19s.
# [flaml.automl.logger: 02-02 22:05:48] {2466} INFO -  at 3.5s,	estimator lgbm's best error=0.4146,	best estimator lgbm's best error=0.4146
# [flaml.automl.logger: 02-02 22:05:48] {2282} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 02-02 22:05:49] {2466} INFO -  at 5.2s,	estimator lgbm's best error=0.3962,	best estimator lgbm's best error=0.3962
# [flaml.automl.logger: 02-02 22:05:49] {2282} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 02-02 22:05:51] {2466} INFO -  at 7.1s,	estimator lgbm's best error=0.3962,	best estimator lgbm's best error=0.3962
# [flaml.automl.logger: 02-02 22:05:51] {2282} INFO - iteration 3, current learner lgbm
# [flaml.automl.logger: 02-02 22:05:53] {2466} INFO -  at 8.8s,	estimator lgbm's best error=0.3962,	best estimator lgbm's best error=0.3962
# [flaml.automl.logger: 02-02 22:05:53] {2282} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 02-02 22:05:55] {2466} INFO -  at 10.7s,	estimator lgbm's best error=0.3962,	best estimator lgbm's best error=0.3962
# [flaml.automl.logger: 02-02 22:05:55] {2282} INFO - iteration 5, current learner lgbm
# [flaml.automl.logger: 02-02 22:05:57] {2466} INFO -  at 12.4s,	estimator lgbm's best error=0.3962,	best estimator lgbm's best error=0.3962
# [flaml.automl.logger: 02-02 22:05:57] {2282} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 02-02 22:05:58] {2466} INFO -  at 14.2s,	estimator lgbm's best error=0.3932,	best estimator lgbm's best error=0.3932
# [flaml.automl.logger: 02-02 22:05:58] {2282} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 02-02 22:06:00] {2466} INFO -  at 15.9s,	estimator lgbm's best error=0.3932,	best estimator lgbm's best error=0.3932
# [flaml.automl.logger: 02-02 22:06:00] {2282} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 02-02 22:06:02] {2466} INFO -  at 17.7s,	estimator lgbm's best error=0.3932,	best estimator lgbm's best error=0.3932
# [flaml.automl.logger: 02-02 22:06:02] {2282} INFO - iteration 9, current learner lgbm
# [flaml.automl.logger: 02-02 22:06:04] {2466} INFO -  at 19.4s,	estimator lgbm's best error=0.3932,	best estimator lgbm's best error=0.3932
# [flaml.automl.logger: 02-02 22:06:04] {2282} INFO - iteration 10, current learner lgbm
# [flaml.automl.logger: 02-02 22:06:06] {2466} INFO -  at 21.5s,	estimator lgbm's best error=0.3694,	best estimator lgbm's best error=0.3694
# [flaml.automl.logger: 02-02 22:06:06] {2282} INFO - iteration 11, current learner lgbm
# [flaml.automl.logger: 02-02 22:06:08] {2466} INFO -  at 23.6s,	estimator lgbm's best error=0.3694,	best estimator lgbm's best error=0.3694
# [flaml.automl.logger: 02-02 22:06:08] {2282} INFO - iteration 12, current learner lgbm
# [flaml.automl.logger: 02-02 22:06:10] {2466} INFO -  at 25.5s,	estimator lgbm's best error=0.3694,	best estimator lgbm's best error=0.3694
# [flaml.automl.logger: 02-02 22:06:10] {2282} INFO - iteration 13, current learner lgbm
# [flaml.automl.logger: 02-02 22:06:11] {2466} INFO -  at 27.2s,	estimator lgbm's best error=0.3694,	best estimator lgbm's best error=0.3694
# [flaml.automl.logger: 02-02 22:06:11] {2282} INFO - iteration 14, current learner lgbm
# [flaml.automl.logger: 02-02 22:06:14] {2466} INFO -  at 29.5s,	estimator lgbm's best error=0.3285,	best estimator lgbm's best error=0.3285
# [flaml.automl.logger: 02-02 22:06:14] {2282} INFO - iteration 15, current learner lgbm
# [flaml.automl.logger: 02-02 22:06:16] {2466} INFO -  at 31.7s,	estimator lgbm's best error=0.3285,	best estimator lgbm's best error=0.3285
# [flaml.automl.logger: 02-02 22:06:16] {2282} INFO - iteration 16, current learner lgbm
# [flaml.automl.logger: 02-02 22:06:18] {2466} INFO -  at 34.1s,	estimator lgbm's best error=0.3285,	best estimator lgbm's best error=0.3285
# [flaml.automl.logger: 02-02 22:06:18] {2282} INFO - iteration 17, current learner lgbm
# [flaml.automl.logger: 02-02 22:06:20] {2466} INFO -  at 36.0s,	estimator lgbm's best error=0.3285,	best estimator lgbm's best error=0.3285
# [flaml.automl.logger: 02-02 22:06:20] {2282} INFO - iteration 18, current learner lgbm
# [flaml.automl.logger: 02-02 22:06:23] {2466} INFO -  at 39.0s,	estimator lgbm's best error=0.3285,	best estimator lgbm's best error=0.3285
# [flaml.automl.logger: 02-02 22:06:23] {2282} INFO - iteration 19, current learner lgbm
# [flaml.automl.logger: 02-02 22:06:25] {2466} INFO -  at 41.0s,	estimator lgbm's best error=0.3285,	best estimator lgbm's best error=0.3285
# [flaml.automl.logger: 02-02 22:06:25] {2282} INFO - iteration 20, current learner lgbm
# [flaml.automl.logger: 02-02 22:06:27] {2466} INFO -  at 43.3s,	estimator lgbm's best error=0.3285,	best estimator lgbm's best error=0.3285
# [flaml.automl.logger: 02-02 22:06:27] {2282} INFO - iteration 21, current learner lgbm
# [flaml.automl.logger: 02-02 22:06:29] {2466} INFO -  at 45.3s,	estimator lgbm's best error=0.3285,	best estimator lgbm's best error=0.3285
# [flaml.automl.logger: 02-02 22:06:29] {2282} INFO - iteration 22, current learner lgbm
# [flaml.automl.logger: 02-02 22:06:32] {2466} INFO -  at 47.5s,	estimator lgbm's best error=0.3285,	best estimator lgbm's best error=0.3285
# [flaml.automl.logger: 02-02 22:06:32] {2282} INFO - iteration 23, current learner lgbm
# [flaml.automl.logger: 02-02 22:06:34] {2466} INFO -  at 50.0s,	estimator lgbm's best error=0.3285,	best estimator lgbm's best error=0.3285
# [flaml.automl.logger: 02-02 22:06:34] {2282} INFO - iteration 24, current learner lgbm
# [flaml.automl.logger: 02-02 22:06:37] {2466} INFO -  at 52.7s,	estimator lgbm's best error=0.3285,	best estimator lgbm's best error=0.3285
# [flaml.automl.logger: 02-02 22:06:37] {2282} INFO - iteration 25, current learner lgbm
# [flaml.automl.logger: 02-02 22:06:40] {2466} INFO -  at 55.7s,	estimator lgbm's best error=0.3285,	best estimator lgbm's best error=0.3285
# [flaml.automl.logger: 02-02 22:06:40] {2282} INFO - iteration 26, current learner lgbm
# [flaml.automl.logger: 02-02 22:06:43] {2466} INFO -  at 58.8s,	estimator lgbm's best error=0.3285,	best estimator lgbm's best error=0.3285
# [flaml.automl.logger: 02-02 22:06:43] {2282} INFO - iteration 27, current learner lgbm
# [flaml.automl.logger: 02-02 22:06:49] {2466} INFO -  at 65.0s,	estimator lgbm's best error=0.3285,	best estimator lgbm's best error=0.3285
# [flaml.automl.logger: 02-02 22:06:49] {2282} INFO - iteration 28, current learner lgbm
# [flaml.automl.logger: 02-02 22:06:55] {2466} INFO -  at 71.0s,	estimator lgbm's best error=0.3285,	best estimator lgbm's best error=0.3285
# [flaml.automl.logger: 02-02 22:06:55] {2282} INFO - iteration 29, current learner lgbm
# [flaml.automl.logger: 02-02 22:07:01] {2466} INFO -  at 76.7s,	estimator lgbm's best error=0.3285,	best estimator lgbm's best error=0.3285
# [flaml.automl.logger: 02-02 22:07:01] {2282} INFO - iteration 30, current learner lgbm
# [flaml.automl.logger: 02-02 22:07:09] {2466} INFO -  at 85.2s,	estimator lgbm's best error=0.3285,	best estimator lgbm's best error=0.3285
# [flaml.automl.logger: 02-02 22:07:09] {2282} INFO - iteration 31, current learner lgbm
# [flaml.automl.logger: 02-02 22:07:18] {2466} INFO -  at 93.5s,	estimator lgbm's best error=0.3285,	best estimator lgbm's best error=0.3285
# [flaml.automl.logger: 02-02 22:07:18] {2282} INFO - iteration 32, current learner lgbm
# [flaml.automl.logger: 02-02 22:07:23] {2466} INFO -  at 99.0s,	estimator lgbm's best error=0.3285,	best estimator lgbm's best error=0.3285
# [flaml.automl.logger: 02-02 22:07:26] {2724} INFO - retrain lgbm for 2.5s
# [flaml.automl.logger: 02-02 22:07:26] {2727} INFO - retrained model: LGBMClassifier(learning_rate=np.float64(0.14632135044822886), max_bin=511,
#                min_child_samples=8, n_estimators=24, n_jobs=-1, num_leaves=4,
#                reg_alpha=0.0009765625,
#                reg_lambda=np.float64(0.07269733706722793), verbose=-1)
# [flaml.automl.logger: 02-02 22:07:26] {2009} INFO - fit succeeded
# [flaml.automl.logger: 02-02 22:07:26] {2010} INFO - Time taken to find the best model: 29.4570951461792
#   [NCI] AUC=0.723
# [flaml.automl.logger: 02-02 22:07:33] {1752} INFO - task = classification
# [flaml.automl.logger: 02-02 22:07:33] {1763} INFO - Evaluation method: cv
# [flaml.automl.logger: 02-02 22:07:33] {1862} INFO - Minimizing error metric: 1-roc_auc
# [flaml.automl.logger: 02-02 22:07:33] {1979} INFO - List of ML learners in AutoML Run: ['lgbm']
# [flaml.automl.logger: 02-02 22:07:33] {2282} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 02-02 22:07:40] {2417} INFO - Estimated sufficient time budget=68297s. Estimated necessary time budget=68s.
# [flaml.automl.logger: 02-02 22:07:40] {2466} INFO -  at 13.3s,	estimator lgbm's best error=0.3226,	best estimator lgbm's best error=0.3226
# [flaml.automl.logger: 02-02 22:07:40] {2282} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 02-02 22:07:46] {2466} INFO -  at 18.8s,	estimator lgbm's best error=0.3226,	best estimator lgbm's best error=0.3226
# [flaml.automl.logger: 02-02 22:07:46] {2282} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 02-02 22:07:51] {2466} INFO -  at 24.0s,	estimator lgbm's best error=0.3150,	best estimator lgbm's best error=0.3150
# [flaml.automl.logger: 02-02 22:07:51] {2282} INFO - iteration 3, current learner lgbm
# [flaml.automl.logger: 02-02 22:07:55] {2466} INFO -  at 28.2s,	estimator lgbm's best error=0.3150,	best estimator lgbm's best error=0.3150
# [flaml.automl.logger: 02-02 22:07:55] {2282} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 02-02 22:08:00] {2466} INFO -  at 33.1s,	estimator lgbm's best error=0.3150,	best estimator lgbm's best error=0.3150
# [flaml.automl.logger: 02-02 22:08:00] {2282} INFO - iteration 5, current learner lgbm
# [flaml.automl.logger: 02-02 22:08:06] {2466} INFO -  at 38.5s,	estimator lgbm's best error=0.3150,	best estimator lgbm's best error=0.3150
# [flaml.automl.logger: 02-02 22:08:06] {2282} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 02-02 22:08:10] {2466} INFO -  at 43.1s,	estimator lgbm's best error=0.3150,	best estimator lgbm's best error=0.3150
# [flaml.automl.logger: 02-02 22:08:10] {2282} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 02-02 22:08:14] {2466} INFO -  at 47.1s,	estimator lgbm's best error=0.3150,	best estimator lgbm's best error=0.3150
# [flaml.automl.logger: 02-02 22:08:14] {2282} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 02-02 22:08:19] {2466} INFO -  at 51.8s,	estimator lgbm's best error=0.3142,	best estimator lgbm's best error=0.3142
# [flaml.automl.logger: 02-02 22:08:19] {2282} INFO - iteration 9, current learner lgbm
# [flaml.automl.logger: 02-02 22:08:24] {2466} INFO -  at 57.4s,	estimator lgbm's best error=0.3142,	best estimator lgbm's best error=0.3142
# [flaml.automl.logger: 02-02 22:08:24] {2282} INFO - iteration 10, current learner lgbm
# [flaml.automl.logger: 02-02 22:08:31] {2466} INFO -  at 64.0s,	estimator lgbm's best error=0.2997,	best estimator lgbm's best error=0.2997
# [flaml.automl.logger: 02-02 22:08:31] {2282} INFO - iteration 11, current learner lgbm
# [flaml.automl.logger: 02-02 22:08:40] {2466} INFO -  at 72.5s,	estimator lgbm's best error=0.2831,	best estimator lgbm's best error=0.2831
# [flaml.automl.logger: 02-02 22:08:40] {2282} INFO - iteration 12, current learner lgbm
# [flaml.automl.logger: 02-02 22:08:47] {2466} INFO -  at 80.2s,	estimator lgbm's best error=0.2831,	best estimator lgbm's best error=0.2831
# [flaml.automl.logger: 02-02 22:08:47] {2282} INFO - iteration 13, current learner lgbm
# [flaml.automl.logger: 02-02 22:08:58] {2466} INFO -  at 90.5s,	estimator lgbm's best error=0.2831,	best estimator lgbm's best error=0.2831
# [flaml.automl.logger: 02-02 22:08:58] {2282} INFO - iteration 14, current learner lgbm
# [flaml.automl.logger: 02-02 22:09:05] {2466} INFO -  at 98.2s,	estimator lgbm's best error=0.2831,	best estimator lgbm's best error=0.2831
# [flaml.automl.logger: 02-02 22:09:08] {2724} INFO - retrain lgbm for 2.9s
# [flaml.automl.logger: 02-02 22:09:08] {2727} INFO - retrained model: LGBMClassifier(colsample_bytree=np.float64(0.9700086872817888),
#                learning_rate=np.float64(0.10936572105917221), max_bin=1023,
#                min_child_samples=22, n_estimators=16, n_jobs=-1, num_leaves=6,
#                reg_alpha=np.float64(0.002977795990973526),
#                reg_lambda=np.float64(0.11093788629585026), verbose=-1)
# [flaml.automl.logger: 02-02 22:09:08] {2009} INFO - fit succeeded
# [flaml.automl.logger: 02-02 22:09:08] {2010} INFO - Time taken to find the best model: 72.5325231552124
#   [AD] AUC=0.780
# [flaml.automl.logger: 02-02 22:09:19] {1752} INFO - task = classification
# [flaml.automl.logger: 02-02 22:09:19] {1763} INFO - Evaluation method: cv
# [flaml.automl.logger: 02-02 22:09:20] {1862} INFO - Minimizing error metric: 1-roc_auc
# [flaml.automl.logger: 02-02 22:09:20] {1979} INFO - List of ML learners in AutoML Run: ['lgbm']
# [flaml.automl.logger: 02-02 22:09:20] {2282} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 02-02 22:09:30] {2417} INFO - Estimated sufficient time budget=108531s. Estimated necessary time budget=109s.
# [flaml.automl.logger: 02-02 22:09:30] {2466} INFO -  at 20.4s,	estimator lgbm's best error=0.1483,	best estimator lgbm's best error=0.1483
# [flaml.automl.logger: 02-02 22:09:30] {2282} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 02-02 22:09:39] {2466} INFO -  at 28.6s,	estimator lgbm's best error=0.1306,	best estimator lgbm's best error=0.1306
# [flaml.automl.logger: 02-02 22:09:39] {2282} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 02-02 22:09:48] {2466} INFO -  at 37.6s,	estimator lgbm's best error=0.1191,	best estimator lgbm's best error=0.1191
# [flaml.automl.logger: 02-02 22:09:48] {2282} INFO - iteration 3, current learner lgbm
# [flaml.automl.logger: 02-02 22:09:55] {2466} INFO -  at 45.1s,	estimator lgbm's best error=0.1191,	best estimator lgbm's best error=0.1191
# [flaml.automl.logger: 02-02 22:09:55] {2282} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 02-02 22:10:04] {2466} INFO -  at 54.1s,	estimator lgbm's best error=0.1191,	best estimator lgbm's best error=0.1191
# [flaml.automl.logger: 02-02 22:10:04] {2282} INFO - iteration 5, current learner lgbm
# [flaml.automl.logger: 02-02 22:10:11] {2466} INFO -  at 60.8s,	estimator lgbm's best error=0.1191,	best estimator lgbm's best error=0.1191
# [flaml.automl.logger: 02-02 22:10:11] {2282} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 02-02 22:10:18] {2466} INFO -  at 67.8s,	estimator lgbm's best error=0.1191,	best estimator lgbm's best error=0.1191
# [flaml.automl.logger: 02-02 22:10:18] {2282} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 02-02 22:10:24] {2466} INFO -  at 73.9s,	estimator lgbm's best error=0.1191,	best estimator lgbm's best error=0.1191
# [flaml.automl.logger: 02-02 22:10:24] {2282} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 02-02 22:10:31] {2466} INFO -  at 80.7s,	estimator lgbm's best error=0.1191,	best estimator lgbm's best error=0.1191
# [flaml.automl.logger: 02-02 22:10:31] {2282} INFO - iteration 9, current learner lgbm
# [flaml.automl.logger: 02-02 22:10:38] {2466} INFO -  at 88.0s,	estimator lgbm's best error=0.1191,	best estimator lgbm's best error=0.1191
# [flaml.automl.logger: 02-02 22:10:38] {2282} INFO - iteration 10, current learner lgbm
# [flaml.automl.logger: 02-02 22:10:50] {2466} INFO -  at 100.3s,	estimator lgbm's best error=0.1191,	best estimator lgbm's best error=0.1191
# [flaml.automl.logger: 02-02 22:10:52] {2724} INFO - retrain lgbm for 1.4s
# [flaml.automl.logger: 02-02 22:10:52] {2727} INFO - retrained model: LGBMClassifier(learning_rate=np.float64(0.09999999999999987), max_bin=255,
#                n_estimators=5, n_jobs=-1, num_leaves=4,
#                reg_alpha=np.float64(0.0009765625), reg_lambda=np.float64(1.0),
#                verbose=-1)
# [flaml.automl.logger: 02-02 22:10:52] {2009} INFO - fit succeeded
# [flaml.automl.logger: 02-02 22:10:52] {2010} INFO - Time taken to find the best model: 37.607266664505005
#   [AD+] AUC=0.499
#
# [Seed 2] Train n=674 | Test n=279 | Groups train=610 test=261
# [flaml.automl.logger: 02-02 22:11:01] {1752} INFO - task = classification
# [flaml.automl.logger: 02-02 22:11:01] {1763} INFO - Evaluation method: cv
# [flaml.automl.logger: 02-02 22:11:01] {1862} INFO - Minimizing error metric: 1-roc_auc
# [flaml.automl.logger: 02-02 22:11:01] {1979} INFO - List of ML learners in AutoML Run: ['lgbm']
# [flaml.automl.logger: 02-02 22:11:01] {2282} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 02-02 22:11:10] {2417} INFO - Estimated sufficient time budget=90903s. Estimated necessary time budget=91s.
# [flaml.automl.logger: 02-02 22:11:10] {2466} INFO -  at 17.2s,	estimator lgbm's best error=0.4595,	best estimator lgbm's best error=0.4595
# [flaml.automl.logger: 02-02 22:11:10] {2282} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 02-02 22:11:20] {2466} INFO -  at 27.0s,	estimator lgbm's best error=0.4517,	best estimator lgbm's best error=0.4517
# [flaml.automl.logger: 02-02 22:11:20] {2282} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 02-02 22:11:27] {2466} INFO -  at 33.7s,	estimator lgbm's best error=0.4517,	best estimator lgbm's best error=0.4517
# [flaml.automl.logger: 02-02 22:11:27] {2282} INFO - iteration 3, current learner lgbm
# [flaml.automl.logger: 02-02 22:11:35] {2466} INFO -  at 41.6s,	estimator lgbm's best error=0.4517,	best estimator lgbm's best error=0.4517
# [flaml.automl.logger: 02-02 22:11:35] {2282} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 02-02 22:11:41] {2466} INFO -  at 48.4s,	estimator lgbm's best error=0.4506,	best estimator lgbm's best error=0.4506
# [flaml.automl.logger: 02-02 22:11:41] {2282} INFO - iteration 5, current learner lgbm
# [flaml.automl.logger: 02-02 22:11:48] {2466} INFO -  at 54.5s,	estimator lgbm's best error=0.4259,	best estimator lgbm's best error=0.4259
# [flaml.automl.logger: 02-02 22:11:48] {2282} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 02-02 22:11:55] {2466} INFO -  at 61.7s,	estimator lgbm's best error=0.4259,	best estimator lgbm's best error=0.4259
# [flaml.automl.logger: 02-02 22:11:55] {2282} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 02-02 22:12:00] {2466} INFO -  at 67.0s,	estimator lgbm's best error=0.4259,	best estimator lgbm's best error=0.4259
# [flaml.automl.logger: 02-02 22:12:00] {2282} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 02-02 22:12:14] {2466} INFO -  at 80.9s,	estimator lgbm's best error=0.4259,	best estimator lgbm's best error=0.4259
# [flaml.automl.logger: 02-02 22:12:14] {2282} INFO - iteration 9, current learner lgbm
# [flaml.automl.logger: 02-02 22:12:22] {2466} INFO -  at 89.0s,	estimator lgbm's best error=0.4259,	best estimator lgbm's best error=0.4259
# [flaml.automl.logger: 02-02 22:12:22] {2282} INFO - iteration 10, current learner lgbm
# [flaml.automl.logger: 02-02 22:12:32] {2466} INFO -  at 99.4s,	estimator lgbm's best error=0.4259,	best estimator lgbm's best error=0.4259
# [flaml.automl.logger: 02-02 22:12:34] {2724} INFO - retrain lgbm for 1.4s
# [flaml.automl.logger: 02-02 22:12:34] {2727} INFO - retrained model: LGBMClassifier(colsample_bytree=np.float64(0.7577252320843954),
#                learning_rate=np.float64(0.006404029194254177), max_bin=63,
#                min_child_samples=56, n_estimators=8, n_jobs=-1, num_leaves=4,
#                reg_alpha=np.float64(0.007141589132511527),
#                reg_lambda=np.float64(1.0357427875187721), verbose=-1)
# [flaml.automl.logger: 02-02 22:12:34] {2009} INFO - fit succeeded
# [flaml.automl.logger: 02-02 22:12:34] {2010} INFO - Time taken to find the best model: 54.50881099700928
#   [MCI] AUC=0.478
# [flaml.automl.logger: 02-02 22:12:42] {1752} INFO - task = classification
# [flaml.automl.logger: 02-02 22:12:42] {1763} INFO - Evaluation method: cv
# [flaml.automl.logger: 02-02 22:12:42] {1862} INFO - Minimizing error metric: 1-roc_auc
# [flaml.automl.logger: 02-02 22:12:42] {1979} INFO - List of ML learners in AutoML Run: ['lgbm']
# [flaml.automl.logger: 02-02 22:12:42] {2282} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 02-02 22:12:50] {2417} INFO - Estimated sufficient time budget=87152s. Estimated necessary time budget=87s.
# [flaml.automl.logger: 02-02 22:12:50] {2466} INFO -  at 14.1s,	estimator lgbm's best error=0.3690,	best estimator lgbm's best error=0.3690
# [flaml.automl.logger: 02-02 22:12:50] {2282} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 02-02 22:13:05] {2466} INFO -  at 29.0s,	estimator lgbm's best error=0.3672,	best estimator lgbm's best error=0.3672
# [flaml.automl.logger: 02-02 22:13:05] {2282} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 02-02 22:13:16] {2466} INFO -  at 39.4s,	estimator lgbm's best error=0.3672,	best estimator lgbm's best error=0.3672
# [flaml.automl.logger: 02-02 22:13:16] {2282} INFO - iteration 3, current learner lgbm
# [flaml.automl.logger: 02-02 22:13:27] {2466} INFO -  at 50.3s,	estimator lgbm's best error=0.3608,	best estimator lgbm's best error=0.3608
# [flaml.automl.logger: 02-02 22:13:27] {2282} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 02-02 22:13:39] {2466} INFO -  at 62.3s,	estimator lgbm's best error=0.3608,	best estimator lgbm's best error=0.3608
# [flaml.automl.logger: 02-02 22:13:39] {2282} INFO - iteration 5, current learner lgbm
# [flaml.automl.logger: 02-02 22:13:48] {2466} INFO -  at 72.0s,	estimator lgbm's best error=0.3608,	best estimator lgbm's best error=0.3608
# [flaml.automl.logger: 02-02 22:13:48] {2282} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 02-02 22:14:01] {2466} INFO -  at 84.9s,	estimator lgbm's best error=0.3332,	best estimator lgbm's best error=0.3332
# [flaml.automl.logger: 02-02 22:14:01] {2282} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 02-02 22:14:11] {2466} INFO -  at 94.4s,	estimator lgbm's best error=0.3332,	best estimator lgbm's best error=0.3332
# [flaml.automl.logger: 02-02 22:14:14] {2724} INFO - retrain lgbm for 2.8s
# [flaml.automl.logger: 02-02 22:14:14] {2727} INFO - retrained model: LGBMClassifier(learning_rate=np.float64(0.10785419066972347), max_bin=1023,
#                min_child_samples=8, n_estimators=13, n_jobs=-1, num_leaves=9,
#                reg_alpha=0.0009765625,
#                reg_lambda=np.float64(0.1598346628655599), verbose=-1)
# [flaml.automl.logger: 02-02 22:14:14] {2009} INFO - fit succeeded
# [flaml.automl.logger: 02-02 22:14:14] {2010} INFO - Time taken to find the best model: 84.94600701332092
#   [NCI] AUC=0.631
# [flaml.automl.logger: 02-02 22:14:20] {1752} INFO - task = classification
# [flaml.automl.logger: 02-02 22:14:20] {1763} INFO - Evaluation method: cv
# [flaml.automl.logger: 02-02 22:14:20] {1862} INFO - Minimizing error metric: 1-roc_auc
# [flaml.automl.logger: 02-02 22:14:20] {1979} INFO - List of ML learners in AutoML Run: ['lgbm']
# [flaml.automl.logger: 02-02 22:14:20] {2282} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 02-02 22:14:27] {2417} INFO - Estimated sufficient time budget=69033s. Estimated necessary time budget=69s.
# [flaml.automl.logger: 02-02 22:14:27] {2466} INFO -  at 12.4s,	estimator lgbm's best error=0.2940,	best estimator lgbm's best error=0.2940
# [flaml.automl.logger: 02-02 22:14:27] {2282} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 02-02 22:14:36] {2466} INFO -  at 21.0s,	estimator lgbm's best error=0.2940,	best estimator lgbm's best error=0.2940
# [flaml.automl.logger: 02-02 22:14:36] {2282} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 02-02 22:14:44] {2466} INFO -  at 28.9s,	estimator lgbm's best error=0.2898,	best estimator lgbm's best error=0.2898
# [flaml.automl.logger: 02-02 22:14:44] {2282} INFO - iteration 3, current learner lgbm
# [flaml.automl.logger: 02-02 22:14:53] {2466} INFO -  at 38.1s,	estimator lgbm's best error=0.2898,	best estimator lgbm's best error=0.2898
# [flaml.automl.logger: 02-02 22:14:53] {2282} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 02-02 22:15:00] {2466} INFO -  at 45.5s,	estimator lgbm's best error=0.2898,	best estimator lgbm's best error=0.2898
# [flaml.automl.logger: 02-02 22:15:00] {2282} INFO - iteration 5, current learner lgbm
# [flaml.automl.logger: 02-02 22:15:07] {2466} INFO -  at 52.6s,	estimator lgbm's best error=0.2898,	best estimator lgbm's best error=0.2898
# [flaml.automl.logger: 02-02 22:15:07] {2282} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 02-02 22:15:17] {2466} INFO -  at 62.3s,	estimator lgbm's best error=0.2898,	best estimator lgbm's best error=0.2898
# [flaml.automl.logger: 02-02 22:15:17] {2282} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 02-02 22:15:24] {2466} INFO -  at 69.0s,	estimator lgbm's best error=0.2898,	best estimator lgbm's best error=0.2898
# [flaml.automl.logger: 02-02 22:15:24] {2282} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 02-02 22:15:32] {2466} INFO -  at 77.3s,	estimator lgbm's best error=0.2898,	best estimator lgbm's best error=0.2898
# [flaml.automl.logger: 02-02 22:15:32] {2282} INFO - iteration 9, current learner lgbm
# [flaml.automl.logger: 02-02 22:15:39] {2466} INFO -  at 84.0s,	estimator lgbm's best error=0.2898,	best estimator lgbm's best error=0.2898
# [flaml.automl.logger: 02-02 22:15:39] {2282} INFO - iteration 10, current learner lgbm
# [flaml.automl.logger: 02-02 22:15:49] {2466} INFO -  at 94.0s,	estimator lgbm's best error=0.2898,	best estimator lgbm's best error=0.2898
# [flaml.automl.logger: 02-02 22:15:50] {2724} INFO - retrain lgbm for 1.2s
# [flaml.automl.logger: 02-02 22:15:50] {2727} INFO - retrained model: LGBMClassifier(learning_rate=np.float64(0.3805001535178522), max_bin=255,
#                min_child_samples=19, n_estimators=4, n_jobs=-1, num_leaves=4,
#                reg_alpha=np.float64(0.001099605873909164),
#                reg_lambda=np.float64(2.457754819866343), verbose=-1)
# [flaml.automl.logger: 02-02 22:15:50] {2009} INFO - fit succeeded
# [flaml.automl.logger: 02-02 22:15:50] {2010} INFO - Time taken to find the best model: 28.868476152420044
#   [AD] AUC=0.687
# [flaml.automl.logger: 02-02 22:16:00] {1752} INFO - task = classification
# [flaml.automl.logger: 02-02 22:16:00] {1763} INFO - Evaluation method: cv
# [flaml.automl.logger: 02-02 22:16:01] {1862} INFO - Minimizing error metric: 1-roc_auc
# [flaml.automl.logger: 02-02 22:16:01] {1979} INFO - List of ML learners in AutoML Run: ['lgbm']
# [flaml.automl.logger: 02-02 22:16:01] {2282} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 02-02 22:16:11] {2417} INFO - Estimated sufficient time budget=98326s. Estimated necessary time budget=98s.
# [flaml.automl.logger: 02-02 22:16:11] {2466} INFO -  at 19.1s,	estimator lgbm's best error=0.0866,	best estimator lgbm's best error=0.0866
# [flaml.automl.logger: 02-02 22:16:11] {2282} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 02-02 22:16:22] {2466} INFO -  at 29.9s,	estimator lgbm's best error=0.0838,	best estimator lgbm's best error=0.0838
# [flaml.automl.logger: 02-02 22:16:22] {2282} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 02-02 22:16:31] {2466} INFO -  at 38.7s,	estimator lgbm's best error=0.0838,	best estimator lgbm's best error=0.0838
# [flaml.automl.logger: 02-02 22:16:31] {2282} INFO - iteration 3, current learner lgbm
# [flaml.automl.logger: 02-02 22:16:40] {2466} INFO -  at 48.1s,	estimator lgbm's best error=0.0690,	best estimator lgbm's best error=0.0690
# [flaml.automl.logger: 02-02 22:16:40] {2282} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 02-02 22:16:50] {2466} INFO -  at 57.8s,	estimator lgbm's best error=0.0690,	best estimator lgbm's best error=0.0690
# [flaml.automl.logger: 02-02 22:16:50] {2282} INFO - iteration 5, current learner lgbm
# [flaml.automl.logger: 02-02 22:16:59] {2466} INFO -  at 66.6s,	estimator lgbm's best error=0.0690,	best estimator lgbm's best error=0.0690
# [flaml.automl.logger: 02-02 22:16:59] {2282} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 02-02 22:17:12] {2466} INFO -  at 79.7s,	estimator lgbm's best error=0.0690,	best estimator lgbm's best error=0.0690
# [flaml.automl.logger: 02-02 22:17:12] {2282} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 02-02 22:17:18] {2466} INFO -  at 85.8s,	estimator lgbm's best error=0.0690,	best estimator lgbm's best error=0.0690
# [flaml.automl.logger: 02-02 22:17:18] {2282} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 02-02 22:17:28] {2466} INFO -  at 96.1s,	estimator lgbm's best error=0.0499,	best estimator lgbm's best error=0.0499
# [flaml.automl.logger: 02-02 22:17:31] {2724} INFO - retrain lgbm for 2.5s
# [flaml.automl.logger: 02-02 22:17:31] {2727} INFO - retrained model: LGBMClassifier(learning_rate=np.float64(0.05809133528925048), max_bin=1023,
#                min_child_samples=9, n_estimators=18, n_jobs=-1, num_leaves=6,
#                reg_alpha=0.0009765625,
#                reg_lambda=np.float64(0.011923154588864114), verbose=-1)
# [flaml.automl.logger: 02-02 22:17:31] {2009} INFO - fit succeeded
# [flaml.automl.logger: 02-02 22:17:31] {2010} INFO - Time taken to find the best model: 96.05038690567017
#   [AD+] AUC=0.750
#
# [Seed 3] Train n=674 | Test n=279 | Groups train=610 test=261
# [flaml.automl.logger: 02-02 22:17:39] {1752} INFO - task = classification
# [flaml.automl.logger: 02-02 22:17:39] {1763} INFO - Evaluation method: cv
# [flaml.automl.logger: 02-02 22:17:39] {1862} INFO - Minimizing error metric: 1-roc_auc
# [flaml.automl.logger: 02-02 22:17:39] {1979} INFO - List of ML learners in AutoML Run: ['lgbm']
# [flaml.automl.logger: 02-02 22:17:39] {2282} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 02-02 22:17:54] {2417} INFO - Estimated sufficient time budget=157158s. Estimated necessary time budget=157s.
# [flaml.automl.logger: 02-02 22:17:54] {2466} INFO -  at 22.2s,	estimator lgbm's best error=0.4694,	best estimator lgbm's best error=0.4694
# [flaml.automl.logger: 02-02 22:17:54] {2282} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 02-02 22:18:02] {2466} INFO -  at 29.7s,	estimator lgbm's best error=0.4694,	best estimator lgbm's best error=0.4694
# [flaml.automl.logger: 02-02 22:18:02] {2282} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 02-02 22:18:09] {2466} INFO -  at 37.0s,	estimator lgbm's best error=0.4574,	best estimator lgbm's best error=0.4574
# [flaml.automl.logger: 02-02 22:18:09] {2282} INFO - iteration 3, current learner lgbm
# [flaml.automl.logger: 02-02 22:18:17] {2466} INFO -  at 44.7s,	estimator lgbm's best error=0.4574,	best estimator lgbm's best error=0.4574
# [flaml.automl.logger: 02-02 22:18:17] {2282} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 02-02 22:18:25] {2466} INFO -  at 53.1s,	estimator lgbm's best error=0.4574,	best estimator lgbm's best error=0.4574
# [flaml.automl.logger: 02-02 22:18:25] {2282} INFO - iteration 5, current learner lgbm
# [flaml.automl.logger: 02-02 22:18:35] {2466} INFO -  at 62.3s,	estimator lgbm's best error=0.4574,	best estimator lgbm's best error=0.4574
# [flaml.automl.logger: 02-02 22:18:35] {2282} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 02-02 22:18:42] {2466} INFO -  at 70.1s,	estimator lgbm's best error=0.4574,	best estimator lgbm's best error=0.4574
# [flaml.automl.logger: 02-02 22:18:42] {2282} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 02-02 22:18:50] {2466} INFO -  at 78.3s,	estimator lgbm's best error=0.4574,	best estimator lgbm's best error=0.4574
# [flaml.automl.logger: 02-02 22:18:50] {2282} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 02-02 22:18:57] {2466} INFO -  at 84.8s,	estimator lgbm's best error=0.4574,	best estimator lgbm's best error=0.4574
# [flaml.automl.logger: 02-02 22:18:57] {2282} INFO - iteration 9, current learner lgbm
# [flaml.automl.logger: 02-02 22:19:04] {2466} INFO -  at 91.9s,	estimator lgbm's best error=0.4574,	best estimator lgbm's best error=0.4574
# [flaml.automl.logger: 02-02 22:19:04] {2282} INFO - iteration 10, current learner lgbm
# [flaml.automl.logger: 02-02 22:19:11] {2466} INFO -  at 98.5s,	estimator lgbm's best error=0.4574,	best estimator lgbm's best error=0.4574
# [flaml.automl.logger: 02-02 22:19:12] {2724} INFO - retrain lgbm for 0.9s
# [flaml.automl.logger: 02-02 22:19:12] {2727} INFO - retrained model: LGBMClassifier(learning_rate=np.float64(0.055049209277364515), max_bin=511,
#                min_child_samples=33, n_estimators=4, n_jobs=-1, num_leaves=4,
#                reg_alpha=np.float64(0.002977773198342582),
#                reg_lambda=np.float64(0.3568918464722918), verbose=-1)
# [flaml.automl.logger: 02-02 22:19:12] {2009} INFO - fit succeeded
# [flaml.automl.logger: 02-02 22:19:12] {2010} INFO - Time taken to find the best model: 36.99213790893555
#   [MCI] AUC=0.575
# [flaml.automl.logger: 02-02 22:19:19] {1752} INFO - task = classification
# [flaml.automl.logger: 02-02 22:19:19] {1763} INFO - Evaluation method: cv
# [flaml.automl.logger: 02-02 22:19:19] {1862} INFO - Minimizing error metric: 1-roc_auc
# [flaml.automl.logger: 02-02 22:19:19] {1979} INFO - List of ML learners in AutoML Run: ['lgbm']
# [flaml.automl.logger: 02-02 22:19:19] {2282} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 02-02 22:19:26] {2417} INFO - Estimated sufficient time budget=68243s. Estimated necessary time budget=68s.
# [flaml.automl.logger: 02-02 22:19:26] {2466} INFO -  at 12.6s,	estimator lgbm's best error=0.3326,	best estimator lgbm's best error=0.3326
# [flaml.automl.logger: 02-02 22:19:26] {2282} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 02-02 22:19:33] {2466} INFO -  at 19.6s,	estimator lgbm's best error=0.3326,	best estimator lgbm's best error=0.3326
# [flaml.automl.logger: 02-02 22:19:33] {2282} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 02-02 22:19:39] {2466} INFO -  at 26.1s,	estimator lgbm's best error=0.3326,	best estimator lgbm's best error=0.3326
# ...
# [flaml.automl.logger: 02-02 22:30:52] {2727} INFO - retrained model: LGBMClassifier(colsample_bytree=np.float64(0.9064025949074165),
#                learning_rate=np.float64(0.0962825851116459), max_bin=127,
#                min_child_samples=11, n_estimators=17, n_jobs=-1, num_leaves=17,
#                reg_alpha=np.float64(0.006537461578873869),
#                reg_lambda=np.float64(0.13065792629706233), verbose=-1)
# [flaml.automl.logger: 02-02 22:30:52] {2009} INFO - fit succeeded
# [flaml.automl.logger: 02-02 22:30:52] {2010} INFO - Time taken to find the best model: 64.64019107818604
#   [AD+] AUC=0.429
#
# [Seed 5] Train n=671 | Test n=282 | Groups train=610 test=261
# [flaml.automl.logger: 02-02 22:31:00] {1752} INFO - task = classification
# [flaml.automl.logger: 02-02 22:31:00] {1763} INFO - Evaluation method: cv
# [flaml.automl.logger: 02-02 22:31:00] {1862} INFO - Minimizing error metric: 1-roc_auc
# [flaml.automl.logger: 02-02 22:31:00] {1979} INFO - List of ML learners in AutoML Run: ['lgbm']
# [flaml.automl.logger: 02-02 22:31:00] {2282} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 02-02 22:31:07] {2417} INFO - Estimated sufficient time budget=66019s. Estimated necessary time budget=66s.
# [flaml.automl.logger: 02-02 22:31:07] {2466} INFO -  at 12.6s,	estimator lgbm's best error=0.4903,	best estimator lgbm's best error=0.4903
# [flaml.automl.logger: 02-02 22:31:07] {2282} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 02-02 22:31:14] {2466} INFO -  at 19.8s,	estimator lgbm's best error=0.4643,	best estimator lgbm's best error=0.4643
# [flaml.automl.logger: 02-02 22:31:14] {2282} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 02-02 22:31:22] {2466} INFO -  at 27.9s,	estimator lgbm's best error=0.4643,	best estimator lgbm's best error=0.4643
# [flaml.automl.logger: 02-02 22:31:22] {2282} INFO - iteration 3, current learner lgbm
# [flaml.automl.logger: 02-02 22:31:30] {2466} INFO -  at 35.8s,	estimator lgbm's best error=0.4643,	best estimator lgbm's best error=0.4643
# [flaml.automl.logger: 02-02 22:31:30] {2282} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 02-02 22:31:35] {2466} INFO -  at 41.5s,	estimator lgbm's best error=0.4643,	best estimator lgbm's best error=0.4643
# [flaml.automl.logger: 02-02 22:31:35] {2282} INFO - iteration 5, current learner lgbm
# [flaml.automl.logger: 02-02 22:31:42] {2466} INFO -  at 47.6s,	estimator lgbm's best error=0.4643,	best estimator lgbm's best error=0.4643
# [flaml.automl.logger: 02-02 22:31:42] {2282} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 02-02 22:31:47] {2466} INFO -  at 53.3s,	estimator lgbm's best error=0.4643,	best estimator lgbm's best error=0.4643
# [flaml.automl.logger: 02-02 22:31:47] {2282} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 02-02 22:31:53] {2466} INFO -  at 59.5s,	estimator lgbm's best error=0.4643,	best estimator lgbm's best error=0.4643
# [flaml.automl.logger: 02-02 22:31:53] {2282} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 02-02 22:32:00] {2466} INFO -  at 65.6s,	estimator lgbm's best error=0.4643,	best estimator lgbm's best error=0.4643
# [flaml.automl.logger: 02-02 22:32:00] {2282} INFO - iteration 9, current learner lgbm
# [flaml.automl.logger: 02-02 22:32:06] {2466} INFO -  at 72.2s,	estimator lgbm's best error=0.4643,	best estimator lgbm's best error=0.4643
# [flaml.automl.logger: 02-02 22:32:06] {2282} INFO - iteration 10, current learner lgbm
# [flaml.automl.logger: 02-02 22:32:12] {2466} INFO -  at 78.5s,	estimator lgbm's best error=0.4643,	best estimator lgbm's best error=0.4643
# [flaml.automl.logger: 02-02 22:32:12] {2282} INFO - iteration 11, current learner lgbm
# [flaml.automl.logger: 02-02 22:32:18] {2466} INFO -  at 84.4s,	estimator lgbm's best error=0.4643,	best estimator lgbm's best error=0.4643
# [flaml.automl.logger: 02-02 22:32:18] {2282} INFO - iteration 12, current learner lgbm
# [flaml.automl.logger: 02-02 22:32:24] {2466} INFO -  at 89.8s,	estimator lgbm's best error=0.4643,	best estimator lgbm's best error=0.4643
# [flaml.automl.logger: 02-02 22:32:24] {2282} INFO - iteration 13, current learner lgbm
# [flaml.automl.logger: 02-02 22:32:29] {2466} INFO -  at 95.2s,	estimator lgbm's best error=0.4643,	best estimator lgbm's best error=0.4643
# [flaml.automl.logger: 02-02 22:32:30] {2724} INFO - retrain lgbm for 0.9s
# [flaml.automl.logger: 02-02 22:32:30] {2727} INFO - retrained model: LGBMClassifier(learning_rate=np.float64(0.060202055233937346), max_bin=63,
#                min_child_samples=22, n_estimators=4, n_jobs=-1, num_leaves=5,
#                reg_alpha=np.float64(0.0034852989888542315),
#                reg_lambda=np.float64(0.1810171895316972), verbose=-1)
# [flaml.automl.logger: 02-02 22:32:30] {2009} INFO - fit succeeded
# [flaml.automl.logger: 02-02 22:32:30] {2010} INFO - Time taken to find the best model: 19.838154077529907
#   [MCI] AUC=0.545
# [flaml.automl.logger: 02-02 22:32:38] {1752} INFO - task = classification
# [flaml.automl.logger: 02-02 22:32:38] {1763} INFO - Evaluation method: cv
# [flaml.automl.logger: 02-02 22:32:38] {1862} INFO - Minimizing error metric: 1-roc_auc
# [flaml.automl.logger: 02-02 22:32:38] {1979} INFO - List of ML learners in AutoML Run: ['lgbm']
# [flaml.automl.logger: 02-02 22:32:38] {2282} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 02-02 22:32:45] {2417} INFO - Estimated sufficient time budget=66530s. Estimated necessary time budget=67s.
# [flaml.automl.logger: 02-02 22:32:45] {2466} INFO -  at 12.7s,	estimator lgbm's best error=0.3773,	best estimator lgbm's best error=0.3773
# [flaml.automl.logger: 02-02 22:32:45] {2282} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 02-02 22:32:51] {2466} INFO -  at 19.0s,	estimator lgbm's best error=0.3773,	best estimator lgbm's best error=0.3773
# [flaml.automl.logger: 02-02 22:32:51] {2282} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 02-02 22:32:58] {2466} INFO -  at 26.2s,	estimator lgbm's best error=0.3720,	best estimator lgbm's best error=0.3720
# [flaml.automl.logger: 02-02 22:32:58] {2282} INFO - iteration 3, current learner lgbm
# [flaml.automl.logger: 02-02 22:33:05] {2466} INFO -  at 33.3s,	estimator lgbm's best error=0.3649,	best estimator lgbm's best error=0.3649
# [flaml.automl.logger: 02-02 22:33:05] {2282} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 02-02 22:33:12] {2466} INFO -  at 40.6s,	estimator lgbm's best error=0.3649,	best estimator lgbm's best error=0.3649
# [flaml.automl.logger: 02-02 22:33:12] {2282} INFO - iteration 5, current learner lgbm
# [flaml.automl.logger: 02-02 22:33:20] {2466} INFO -  at 47.9s,	estimator lgbm's best error=0.3616,	best estimator lgbm's best error=0.3616
# [flaml.automl.logger: 02-02 22:33:20] {2282} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 02-02 22:33:27] {2466} INFO -  at 55.7s,	estimator lgbm's best error=0.3495,	best estimator lgbm's best error=0.3495
# [flaml.automl.logger: 02-02 22:33:27] {2282} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 02-02 22:33:36] {2466} INFO -  at 64.4s,	estimator lgbm's best error=0.3495,	best estimator lgbm's best error=0.3495
# [flaml.automl.logger: 02-02 22:33:36] {2282} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 02-02 22:33:44] {2466} INFO -  at 72.5s,	estimator lgbm's best error=0.3495,	best estimator lgbm's best error=0.3495
# [flaml.automl.logger: 02-02 22:33:44] {2282} INFO - iteration 9, current learner lgbm
# [flaml.automl.logger: 02-02 22:33:55] {2466} INFO -  at 83.0s,	estimator lgbm's best error=0.3345,	best estimator lgbm's best error=0.3345
# [flaml.automl.logger: 02-02 22:33:55] {2282} INFO - iteration 10, current learner lgbm
# [flaml.automl.logger: 02-02 22:34:02] {2466} INFO -  at 90.3s,	estimator lgbm's best error=0.3345,	best estimator lgbm's best error=0.3345
# [flaml.automl.logger: 02-02 22:34:04] {2724} INFO - retrain lgbm for 1.9s
# [flaml.automl.logger: 02-02 22:34:04] {2727} INFO - retrained model: LGBMClassifier(colsample_bytree=np.float64(0.7142683551379817),
#                learning_rate=np.float64(0.23033364878948764), max_bin=255,
#                min_child_samples=49, n_estimators=16, n_jobs=-1, num_leaves=7,
#                reg_alpha=np.float64(0.003935560049801619),
#                reg_lambda=np.float64(9.021142394190072), verbose=-1)
# [flaml.automl.logger: 02-02 22:34:04] {2009} INFO - fit succeeded
# [flaml.automl.logger: 02-02 22:34:04] {2010} INFO - Time taken to find the best model: 83.03406882286072
#   [NCI] AUC=0.649
# [flaml.automl.logger: 02-02 22:34:11] {1752} INFO - task = classification
# [flaml.automl.logger: 02-02 22:34:11] {1763} INFO - Evaluation method: cv
# [flaml.automl.logger: 02-02 22:34:11] {1862} INFO - Minimizing error metric: 1-roc_auc
# [flaml.automl.logger: 02-02 22:34:11] {1979} INFO - List of ML learners in AutoML Run: ['lgbm']
# [flaml.automl.logger: 02-02 22:34:11] {2282} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 02-02 22:34:18] {2417} INFO - Estimated sufficient time budget=68616s. Estimated necessary time budget=69s.
# [flaml.automl.logger: 02-02 22:34:18] {2466} INFO -  at 12.9s,	estimator lgbm's best error=0.2969,	best estimator lgbm's best error=0.2969
# [flaml.automl.logger: 02-02 22:34:18] {2282} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 02-02 22:34:24] {2466} INFO -  at 19.0s,	estimator lgbm's best error=0.2969,	best estimator lgbm's best error=0.2969
# [flaml.automl.logger: 02-02 22:34:24] {2282} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 02-02 22:34:31] {2466} INFO -  at 26.2s,	estimator lgbm's best error=0.2969,	best estimator lgbm's best error=0.2969
# [flaml.automl.logger: 02-02 22:34:31] {2282} INFO - iteration 3, current learner lgbm
# [flaml.automl.logger: 02-02 22:34:39] {2466} INFO -  at 33.2s,	estimator lgbm's best error=0.2627,	best estimator lgbm's best error=0.2627
# [flaml.automl.logger: 02-02 22:34:39] {2282} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 02-02 22:34:45] {2466} INFO -  at 40.2s,	estimator lgbm's best error=0.2627,	best estimator lgbm's best error=0.2627
# [flaml.automl.logger: 02-02 22:34:45] {2282} INFO - iteration 5, current learner lgbm
# [flaml.automl.logger: 02-02 22:34:52] {2466} INFO -  at 47.2s,	estimator lgbm's best error=0.2627,	best estimator lgbm's best error=0.2627
# [flaml.automl.logger: 02-02 22:34:52] {2282} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 02-02 22:34:59] {2466} INFO -  at 53.5s,	estimator lgbm's best error=0.2627,	best estimator lgbm's best error=0.2627
# [flaml.automl.logger: 02-02 22:34:59] {2282} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 02-02 22:35:07] {2466} INFO -  at 61.9s,	estimator lgbm's best error=0.2452,	best estimator lgbm's best error=0.2452
# [flaml.automl.logger: 02-02 22:35:07] {2282} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 02-02 22:35:15] {2466} INFO -  at 70.0s,	estimator lgbm's best error=0.2452,	best estimator lgbm's best error=0.2452
# [flaml.automl.logger: 02-02 22:35:15] {2282} INFO - iteration 9, current learner lgbm
# [flaml.automl.logger: 02-02 22:35:22] {2466} INFO -  at 77.2s,	estimator lgbm's best error=0.2362,	best estimator lgbm's best error=0.2362
# [flaml.automl.logger: 02-02 22:35:22] {2282} INFO - iteration 10, current learner lgbm
# [flaml.automl.logger: 02-02 22:35:30] {2466} INFO -  at 85.1s,	estimator lgbm's best error=0.2362,	best estimator lgbm's best error=0.2362
# [flaml.automl.logger: 02-02 22:35:30] {2282} INFO - iteration 11, current learner lgbm
# [flaml.automl.logger: 02-02 22:35:40] {2466} INFO -  at 95.1s,	estimator lgbm's best error=0.2362,	best estimator lgbm's best error=0.2362
# [flaml.automl.logger: 02-02 22:35:42] {2724} INFO - retrain lgbm for 1.3s
# [flaml.automl.logger: 02-02 22:35:42] {2727} INFO - retrained model: LGBMClassifier(colsample_bytree=np.float64(0.9125000255612622),
#                learning_rate=np.float64(0.22812480042284042), max_bin=63,
#                min_child_samples=99, n_estimators=19, n_jobs=-1, num_leaves=7,
#                reg_alpha=0.0009765625,
#                reg_lambda=np.float64(0.2060257044212581), verbose=-1)
# [flaml.automl.logger: 02-02 22:35:42] {2009} INFO - fit succeeded
# [flaml.automl.logger: 02-02 22:35:42] {2010} INFO - Time taken to find the best model: 77.1784930229187
#   [AD] AUC=0.695
# [flaml.automl.logger: 02-02 22:35:49] {1752} INFO - task = classification
# [flaml.automl.logger: 02-02 22:35:49] {1763} INFO - Evaluation method: cv
# [flaml.automl.logger: 02-02 22:35:49] {1862} INFO - Minimizing error metric: 1-roc_auc
# [flaml.automl.logger: 02-02 22:35:49] {1979} INFO - List of ML learners in AutoML Run: ['lgbm']
# [flaml.automl.logger: 02-02 22:35:49] {2282} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 02-02 22:35:56] {2417} INFO - Estimated sufficient time budget=70579s. Estimated necessary time budget=71s.
# [flaml.automl.logger: 02-02 22:35:56] {2466} INFO -  at 13.1s,	estimator lgbm's best error=0.1202,	best estimator lgbm's best error=0.1202
# [flaml.automl.logger: 02-02 22:35:56] {2282} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 02-02 22:36:03] {2466} INFO -  at 19.7s,	estimator lgbm's best error=0.1202,	best estimator lgbm's best error=0.1202
# [flaml.automl.logger: 02-02 22:36:03] {2282} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 02-02 22:36:10] {2466} INFO -  at 26.7s,	estimator lgbm's best error=0.0516,	best estimator lgbm's best error=0.0516
# [flaml.automl.logger: 02-02 22:36:10] {2282} INFO - iteration 3, current learner lgbm
# [flaml.automl.logger: 02-02 22:36:18] {2466} INFO -  at 34.6s,	estimator lgbm's best error=0.0170,	best estimator lgbm's best error=0.0170
# [flaml.automl.logger: 02-02 22:36:18] {2282} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 02-02 22:36:25] {2466} INFO -  at 41.9s,	estimator lgbm's best error=0.0170,	best estimator lgbm's best error=0.0170
# [flaml.automl.logger: 02-02 22:36:25] {2282} INFO - iteration 5, current learner lgbm
# [flaml.automl.logger: 02-02 22:36:33] {2466} INFO -  at 49.8s,	estimator lgbm's best error=0.0170,	best estimator lgbm's best error=0.0170
# [flaml.automl.logger: 02-02 22:36:33] {2282} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 02-02 22:36:41] {2466} INFO -  at 57.8s,	estimator lgbm's best error=0.0170,	best estimator lgbm's best error=0.0170
# [flaml.automl.logger: 02-02 22:36:41] {2282} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 02-02 22:36:50] {2466} INFO -  at 66.8s,	estimator lgbm's best error=0.0128,	best estimator lgbm's best error=0.0128
# [flaml.automl.logger: 02-02 22:36:50] {2282} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 02-02 22:36:58] {2466} INFO -  at 74.9s,	estimator lgbm's best error=0.0112,	best estimator lgbm's best error=0.0112
# [flaml.automl.logger: 02-02 22:36:58] {2282} INFO - iteration 9, current learner lgbm
# [flaml.automl.logger: 02-02 22:37:07] {2466} INFO -  at 84.0s,	estimator lgbm's best error=0.0079,	best estimator lgbm's best error=0.0079
# [flaml.automl.logger: 02-02 22:37:07] {2282} INFO - iteration 10, current learner lgbm
# [flaml.automl.logger: 02-02 22:37:14] {2466} INFO -  at 91.3s,	estimator lgbm's best error=0.0079,	best estimator lgbm's best error=0.0079
# [flaml.automl.logger: 02-02 22:37:16] {2724} INFO - retrain lgbm for 1.9s
# [flaml.automl.logger: 02-02 22:37:16] {2727} INFO - retrained model: LGBMClassifier(colsample_bytree=np.float64(0.8592055279110546),
#                learning_rate=np.float64(0.230333648789488), max_bin=255,
#                min_child_samples=49, n_estimators=16, n_jobs=-1, num_leaves=12,
#                reg_alpha=np.float64(0.0011187653015894306),
#                reg_lambda=np.float64(9.021142394190072), verbose=-1)
# [flaml.automl.logger: 02-02 22:37:16] {2009} INFO - fit succeeded
# [flaml.automl.logger: 02-02 22:37:16] {2010} INFO - Time taken to find the best model: 84.04148507118225
#   [AD+] AUC=0.613
